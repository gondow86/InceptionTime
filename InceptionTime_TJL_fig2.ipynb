# %%
#|export
from tsai.imports import *
from tsai.models.layers import *
from torchinfo import summary

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
from scipy import signal
# from tqdm.notebook import tqdm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# hyper parameter
num_classes = 30
close_num = 14 # 14, 19, 24, 29
batch_size = 64
learning_rate = 0.0001
num_epochs = 300
down_ratio = 8
sequence_len = 2000 * 5 // down_ratio # default 2000Hz
overlap = int(sequence_len * 0.3)
threshold = 0.998
thresholds = [0.3, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70, 0.75, 0.80]
close_nums = [14, 19, 24, 29]
alpha = 0.1

# %%
radar_frame_list = []
scaler = MinMaxScaler((-1, 1)) # or StandardScaler

for i in range(1, num_classes + 1):
    # wave_2d = [] # input need to be 2d?
    file_path = "./data/radar_%02d.csv" % i # or ./data/radar_%02d
    radar_frame = pd.read_csv(file_path)
    wave = radar_frame.to_numpy().flatten()
    wave = signal.decimate(wave, down_ratio) # down sampling
    
    end = len(wave)
    n = 0
    n_stop = sequence_len
    wave_segments = []

    while n_stop < end:
        n_start = 0 + ((sequence_len - 1) - (overlap - 1)) * n
        n_stop = n_start + sequence_len
        tmp = []
        seg = wave[n_start:n_stop].copy()
        wave_segments.append([seg])
        n += 1
    
    radar_frame_list.append(wave_segments)

data_df = pd.DataFrame(radar_frame_list)

# %%
labels = []
for i in range(len(radar_frame_list)):
    for j in range(len(radar_frame_list[i])):
        if i <= close_num:
            labels.append(i)
        else:
            labels.append(close_num + 1)

labels_series = pd.Series(labels)

# %%
tmp = data_df.to_numpy().flatten().copy()
data_series = pd.Series(tmp).dropna() # remove None (keys are as they are)
tmp = data_series.to_numpy().flatten()

tmp_labels = labels_series.to_numpy().flatten()
# len(tmp) = 5442 (30人分のデータ)
# len(tmp[0]) = 1 (in_channelが1のため)
# len(tmp[0][0]) = 1250 (sequence_len)

for i in reversed(range(len(tmp))):
  if len(tmp[i][0]) != sequence_len:
    # print(i, len(tmp[i][0]))
    tmp = np.delete(tmp, i)
    tmp_labels = np.delete(tmp_labels, i)

data_series = pd.Series(tmp)
labels_series = pd.Series(tmp_labels)
labels_tensor = torch.tensor(labels_series)
data_series.shape, labels_tensor, labels_tensor.shape
# Out:
# ((5413,), tensor([ 0,  0,  0,  ..., 15, 15, 15]), torch.Size([5413]))

# %%
class InceptionModule(Module):
    def __init__(self, ni, nf, ks=40, bottleneck=True):
        ks = [ks // (2**i) for i in range(3)]
        ks = [k if k % 2 != 0 else k - 1 for k in ks]  # ensure odd ks
        bottleneck = bottleneck if ni > 1 else False
        self.bottleneck = Conv1d(ni, nf, 1, bias=False) if bottleneck else noop
        self.convs = nn.ModuleList([Conv1d(nf if bottleneck else ni, nf, k, bias=False) for k in ks])
        self.maxconvpool = nn.Sequential(*[nn.MaxPool1d(3, stride=1, padding=1), Conv1d(ni, nf, 1, bias=False)])
        self.concat = Concat()
        self.bn = BN1d(nf * 4)
        self.act = nn.ReLU()

    def forward(self, x):
        input_tensor = x
        x = self.bottleneck(input_tensor)
        x = self.concat([l(x) for l in self.convs] + [self.maxconvpool(input_tensor)])
        return self.act(self.bn(x))


@delegates(InceptionModule.__init__)
class InceptionBlock(Module):
    def __init__(self, ni, nf=32, residual=True, depth=6, **kwargs):
        self.residual, self.depth = residual, depth
        self.inception, self.shortcut = nn.ModuleList(), nn.ModuleList()
        for d in range(depth):
            self.inception.append(InceptionModule(ni if d == 0 else nf * 4, nf, **kwargs))
            if self.residual and d % 3 == 2: 
                n_in, n_out = ni if d == 2 else nf * 4, nf * 4
                self.shortcut.append(BN1d(n_in) if n_in == n_out else ConvBlock(n_in, n_out, 1, act=None))
        self.add = Add()
        self.act = nn.ReLU()
        
    def forward(self, x):
        res = x
        for d, l in enumerate(range(self.depth)):
            x = self.inception[d](x)
            if self.residual and d % 3 == 2: res = x = self.act(self.add(x, self.shortcut[d//3](res)))
        return x

    
@delegates(InceptionModule.__init__)
class InceptionTime(Module):
    def __init__(self, c_in, c_out, seq_len=None, nf=32, nb_filters=None, **kwargs):
        nf = ifnone(nf, nb_filters) # for compatibility
        self.inceptionblock = InceptionBlock(c_in, nf, **kwargs) # c_in is input channel num of conv1d
        self.gap = GAP1d(1)
        self.fc = nn.Linear(nf * 4, c_out) # c_out is 1d output size 
        self.fc_tsne = nn.Linear(nf * 4, 2)
        self.two_vecs_train = [] # list is faster in appending
        self.two_vecs_test = []

    def forward(self, x):
        x = self.inceptionblock(x)
        x = self.gap(x)
        two_dimensional_vec = self.fc_tsne(x)
        if self.training:
            self.two_vecs_train.append(two_dimensional_vec.tolist()) # あとでネストしたものをまとめてtensorかndarrayに変換するため
        else:
            self.two_vecs_test.append(two_dimensional_vec.tolist())
        x = self.fc(x)
        return x

# %% [markdown]
# Reshapeかviewで(-1, 128, 2)の形にする
#
# ちゃんと望んだ形と要素になっているか確認する

# %% [markdown]
# 各エポックのうち34個目のバッチだけ40個になっている。(34 * 300 = 10200)
#
# labelも34バッチ目だけ消せる？
# DataLoaderから取り出せるか

# %%
labels_1epoch = []
for i, data in enumerate(train_loader):
    x, y = data
    if i != 32 and i != 33: # don't append batch 33, 34
        labels_1epoch.append(torch.Tensor.tolist(y))

labels_1epoch_np = np.array(labels_1epoch)
labels_1epoch_reshaped = np.reshape(labels_1epoch_np, (16, 128))
labels_1epoch_reshaped.shape
# Out:
# (16, 128)

# %%
tmp = model.two_vecs_train[:]
for i, t in reversed(list(enumerate(tmp))):
    if len(t) != batch_size or i % 33 == 0:
        # print(i, len(t))
        del tmp[i]

tmp = np.array(tmp)
tmp.shape
# Out:
# (9600, 64, 2)

# %% [markdown]
# 最後３３番目の要素を使ってないだけ

# %%
tmp_reshaped = np.reshape(tmp, (4800, 128, 2))
tmp_reshaped.shape
# Out:
# (4800, 128, 2)

# %% [markdown]
# Labelと2次元ベクトルの対応ができた。
#
# あとは色を指定するときに、Labelと色を対応させる。

# %%
plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.get_cmap("tab20").colors)
color_map = {0:(0.121, 0.466, 0.705), 1:(0.682, 0.780, 0.909), 2:(1.0, 0.498, 0.054), 3:(1.0, 0.7333333333333333, 0.47058823529411764), 4:(0.17254901960784313, 0.6274509803921569, 0.17254901960784313), 5:(0.596078431372549, 0.8745098039215686, 0.5411764705882353), 6:(0.8392156862745098, 0.15294117647058825, 0.1568627450980392), 7:(1.0, 0.596078431372549, 0.5882352941176471), 8:(0.5803921568627451, 0.403921568627451, 0.7411764705882353), 9:(0.7725490196078432, 0.6901960784313725, 0.8352941176470589), 10:(0.5490196078431373, 0.33725490196078434, 0.29411764705882354), 11:(0.7686274509803922, 0.611764705882353, 0.5803921568627451), 12:(0.8901960784313725, 0.4666666666666667, 0.7607843137254902), 13:(0.9686274509803922, 0.7137254901960784, 0.8235294117647058), 14:(0.4980392156862745, 0.4980392156862745, 0.4980392156862745), 15:(0.7803921568627451, 0.7803921568627451, 0.7803921568627451)}

# %%
tmp_reshaped.shape, labels_1epoch_reshaped.shape
# Out:
# ((4800, 128, 2), (16, 128))

# %%
# 16no baisuu
epoch = 0
for i in range(4800):
    label_idx = i % 16 # (num_sample / batchsize - 2) / 2
    two_vecs = tmp_reshaped[i]
    plt.clf() # init
    if label_idx == 0:
        epoch += 1
    file_name = "%03d_%02d_Fmap.png" % (epoch, label_idx)
    print(file_name)
    for j, vec in enumerate(two_vecs):
        label = labels_1epoch_reshaped[label_idx][j]
        plt.scatter(vec[0], vec[1], color=color_map[label])
    plt.savefig("./figure/feature_map/" + file_name)
# Out:
# 001_00_Fmap.png
# 001_01_Fmap.png
# 001_02_Fmap.png
# 001_03_Fmap.png
# 001_04_Fmap.png
# 001_05_Fmap.png
# 001_06_Fmap.png
# 001_07_Fmap.png
# 001_08_Fmap.png
# 001_09_Fmap.png
# 001_10_Fmap.png
# 001_11_Fmap.png
# 001_12_Fmap.png
# 001_13_Fmap.png
# 001_14_Fmap.png
# 001_15_Fmap.png
# 002_00_Fmap.png
# 002_01_Fmap.png
# 002_02_Fmap.png
# 002_03_Fmap.png
# 002_04_Fmap.png
# 002_05_Fmap.png
# 002_06_Fmap.png
# 002_07_Fmap.png
# 002_08_Fmap.png
# 002_09_Fmap.png
# 002_10_Fmap.png
# 002_11_Fmap.png
# 002_12_Fmap.png
# 002_13_Fmap.png
# 002_14_Fmap.png
# 002_15_Fmap.png
# 003_00_Fmap.png
# 003_01_Fmap.png
# 003_02_Fmap.png
# 003_03_Fmap.png
# 003_04_Fmap.png
# 003_05_Fmap.png
# 003_06_Fmap.png
# 003_07_Fmap.png
# 003_08_Fmap.png
# 003_09_Fmap.png
# 003_10_Fmap.png
# 003_11_Fmap.png
# 003_12_Fmap.png
# 003_13_Fmap.png
# 003_14_Fmap.png
# 003_15_Fmap.png
# 004_00_Fmap.png
# 004_01_Fmap.png
# 004_02_Fmap.png
# 004_03_Fmap.png
# 004_04_Fmap.png
# 004_05_Fmap.png
# 004_06_Fmap.png
# 004_07_Fmap.png
# 004_08_Fmap.png
# 004_09_Fmap.png
# 004_10_Fmap.png
# 004_11_Fmap.png
# 004_12_Fmap.png
# 004_13_Fmap.png
# 004_14_Fmap.png
# 004_15_Fmap.png
# 005_00_Fmap.png
# 005_01_Fmap.png
# 005_02_Fmap.png
# 005_03_Fmap.png
# 005_04_Fmap.png
# 005_05_Fmap.png
# 005_06_Fmap.png
# 005_07_Fmap.png
# 005_08_Fmap.png
# 005_09_Fmap.png
# 005_10_Fmap.png
# 005_11_Fmap.png
# 005_12_Fmap.png
# 005_13_Fmap.png
# 005_14_Fmap.png
# 005_15_Fmap.png
# 006_00_Fmap.png
# 006_01_Fmap.png
# 006_02_Fmap.png
# 006_03_Fmap.png
# 006_04_Fmap.png
# 006_05_Fmap.png
# 006_06_Fmap.png
# 006_07_Fmap.png
# 006_08_Fmap.png
# 006_09_Fmap.png
# 006_10_Fmap.png
# 006_11_Fmap.png
# 006_12_Fmap.png
# 006_13_Fmap.png
# 006_14_Fmap.png
# 006_15_Fmap.png
# 007_00_Fmap.png
# 007_01_Fmap.png
# 007_02_Fmap.png
# 007_03_Fmap.png
# 007_04_Fmap.png
# 007_05_Fmap.png
# 007_06_Fmap.png
# 007_07_Fmap.png
# 007_08_Fmap.png
# 007_09_Fmap.png
# 007_10_Fmap.png
# 007_11_Fmap.png
# 007_12_Fmap.png
# 007_13_Fmap.png
# 007_14_Fmap.png
# 007_15_Fmap.png
# 008_00_Fmap.png
# 008_01_Fmap.png
# 008_02_Fmap.png
# 008_03_Fmap.png
# 008_04_Fmap.png
# 008_05_Fmap.png
# 008_06_Fmap.png
# 008_07_Fmap.png
# 008_08_Fmap.png
# 008_09_Fmap.png
# 008_10_Fmap.png
# 008_11_Fmap.png
# 008_12_Fmap.png
# 008_13_Fmap.png
# 008_14_Fmap.png
# 008_15_Fmap.png
# 009_00_Fmap.png
# 009_01_Fmap.png
# 009_02_Fmap.png
# 009_03_Fmap.png
# 009_04_Fmap.png
# 009_05_Fmap.png
# 009_06_Fmap.png
# 009_07_Fmap.png
# 009_08_Fmap.png
# 009_09_Fmap.png
# 009_10_Fmap.png
# 009_11_Fmap.png
# 009_12_Fmap.png
# 009_13_Fmap.png
# 009_14_Fmap.png
# 009_15_Fmap.png
# 010_00_Fmap.png
# 010_01_Fmap.png
# 010_02_Fmap.png
# 010_03_Fmap.png
# 010_04_Fmap.png
# 010_05_Fmap.png
# 010_06_Fmap.png
# 010_07_Fmap.png
# 010_08_Fmap.png
# 010_09_Fmap.png
# 010_10_Fmap.png
# 010_11_Fmap.png
# 010_12_Fmap.png
# 010_13_Fmap.png
# 010_14_Fmap.png
# 010_15_Fmap.png
# 011_00_Fmap.png
# 011_01_Fmap.png
# 011_02_Fmap.png
# 011_03_Fmap.png
# 011_04_Fmap.png
# 011_05_Fmap.png
# 011_06_Fmap.png
# 011_07_Fmap.png
# 011_08_Fmap.png
# 011_09_Fmap.png
# 011_10_Fmap.png
# 011_11_Fmap.png
# 011_12_Fmap.png
# 011_13_Fmap.png
# 011_14_Fmap.png
# 011_15_Fmap.png
# 012_00_Fmap.png
# 012_01_Fmap.png
# 012_02_Fmap.png
# 012_03_Fmap.png
# 012_04_Fmap.png
# 012_05_Fmap.png
# 012_06_Fmap.png
# 012_07_Fmap.png
# 012_08_Fmap.png
# 012_09_Fmap.png
# 012_10_Fmap.png
# 012_11_Fmap.png
# 012_12_Fmap.png
# 012_13_Fmap.png
# 012_14_Fmap.png
# 012_15_Fmap.png
# 013_00_Fmap.png
# 013_01_Fmap.png
# 013_02_Fmap.png
# 013_03_Fmap.png
# 013_04_Fmap.png
# 013_05_Fmap.png
# 013_06_Fmap.png
# 013_07_Fmap.png
# 013_08_Fmap.png
# 013_09_Fmap.png
# 013_10_Fmap.png
# 013_11_Fmap.png
# 013_12_Fmap.png
# 013_13_Fmap.png
# 013_14_Fmap.png
# 013_15_Fmap.png
# 014_00_Fmap.png
# 014_01_Fmap.png
# 014_02_Fmap.png
# 014_03_Fmap.png
# 014_04_Fmap.png
# 014_05_Fmap.png
# 014_06_Fmap.png
# 014_07_Fmap.png
# 014_08_Fmap.png
# 014_09_Fmap.png
# 014_10_Fmap.png
# 014_11_Fmap.png
# 014_12_Fmap.png
# 014_13_Fmap.png
# 014_14_Fmap.png
# 014_15_Fmap.png
# 015_00_Fmap.png
# 015_01_Fmap.png
# 015_02_Fmap.png
# 015_03_Fmap.png
# 015_04_Fmap.png
# 015_05_Fmap.png
# 015_06_Fmap.png
# 015_07_Fmap.png
# 015_08_Fmap.png
# 015_09_Fmap.png
# 015_10_Fmap.png
# 015_11_Fmap.png
# 015_12_Fmap.png
# 015_13_Fmap.png
# 015_14_Fmap.png
# 015_15_Fmap.png
# 016_00_Fmap.png
# 016_01_Fmap.png
# 016_02_Fmap.png
# 016_03_Fmap.png
# 016_04_Fmap.png
# 016_05_Fmap.png
# 016_06_Fmap.png
# 016_07_Fmap.png
# 016_08_Fmap.png
# 016_09_Fmap.png
# 016_10_Fmap.png
# 016_11_Fmap.png
# 016_12_Fmap.png
# 016_13_Fmap.png
# 016_14_Fmap.png
# 016_15_Fmap.png
# 017_00_Fmap.png
# 017_01_Fmap.png
# 017_02_Fmap.png
# 017_03_Fmap.png
# 017_04_Fmap.png
# 017_05_Fmap.png
# 017_06_Fmap.png
# 017_07_Fmap.png
# 017_08_Fmap.png
# 017_09_Fmap.png
# 017_10_Fmap.png
# 017_11_Fmap.png
# 017_12_Fmap.png
# 017_13_Fmap.png
# 017_14_Fmap.png
# 017_15_Fmap.png
# 018_00_Fmap.png
# 018_01_Fmap.png
# 018_02_Fmap.png
# 018_03_Fmap.png
# 018_04_Fmap.png
# 018_05_Fmap.png
# 018_06_Fmap.png
# 018_07_Fmap.png
# 018_08_Fmap.png
# 018_09_Fmap.png
# 018_10_Fmap.png
# 018_11_Fmap.png
# 018_12_Fmap.png
# 018_13_Fmap.png
# 018_14_Fmap.png
# 018_15_Fmap.png
# 019_00_Fmap.png
# 019_01_Fmap.png
# 019_02_Fmap.png
# 019_03_Fmap.png
# 019_04_Fmap.png
# 019_05_Fmap.png
# 019_06_Fmap.png
# 019_07_Fmap.png
# 019_08_Fmap.png
# 019_09_Fmap.png
# 019_10_Fmap.png
# 019_11_Fmap.png
# 019_12_Fmap.png
# 019_13_Fmap.png
# 019_14_Fmap.png
# 019_15_Fmap.png
# 020_00_Fmap.png
# 020_01_Fmap.png
# 020_02_Fmap.png
# 020_03_Fmap.png
# 020_04_Fmap.png
# 020_05_Fmap.png
# 020_06_Fmap.png
# 020_07_Fmap.png
# 020_08_Fmap.png
# 020_09_Fmap.png
# 020_10_Fmap.png
# 020_11_Fmap.png
# 020_12_Fmap.png
# 020_13_Fmap.png
# 020_14_Fmap.png
# 020_15_Fmap.png
# 021_00_Fmap.png
# 021_01_Fmap.png
# 021_02_Fmap.png
# 021_03_Fmap.png
# 021_04_Fmap.png
# 021_05_Fmap.png
# 021_06_Fmap.png
# 021_07_Fmap.png
# 021_08_Fmap.png
# 021_09_Fmap.png
# 021_10_Fmap.png
# 021_11_Fmap.png
# 021_12_Fmap.png
# 021_13_Fmap.png
# 021_14_Fmap.png
# 021_15_Fmap.png
# 022_00_Fmap.png
# 022_01_Fmap.png
# 022_02_Fmap.png
# 022_03_Fmap.png
# 022_04_Fmap.png
# 022_05_Fmap.png
# 022_06_Fmap.png
# 022_07_Fmap.png
# 022_08_Fmap.png
# 022_09_Fmap.png
# 022_10_Fmap.png
# 022_11_Fmap.png
# 022_12_Fmap.png
# 022_13_Fmap.png
# 022_14_Fmap.png
# 022_15_Fmap.png
# 023_00_Fmap.png
# 023_01_Fmap.png
# 023_02_Fmap.png
# 023_03_Fmap.png
# 023_04_Fmap.png
# 023_05_Fmap.png
# 023_06_Fmap.png
# 023_07_Fmap.png
# 023_08_Fmap.png
# 023_09_Fmap.png
# 023_10_Fmap.png
# 023_11_Fmap.png
# 023_12_Fmap.png
# 023_13_Fmap.png
# 023_14_Fmap.png
# 023_15_Fmap.png
# 024_00_Fmap.png
# 024_01_Fmap.png
# 024_02_Fmap.png
# 024_03_Fmap.png
# 024_04_Fmap.png
# 024_05_Fmap.png
# 024_06_Fmap.png
# 024_07_Fmap.png
# 024_08_Fmap.png
# 024_09_Fmap.png
# 024_10_Fmap.png
# 024_11_Fmap.png
# 024_12_Fmap.png
# 024_13_Fmap.png
# 024_14_Fmap.png
# 024_15_Fmap.png
# 025_00_Fmap.png
# 025_01_Fmap.png
# 025_02_Fmap.png
# 025_03_Fmap.png
# 025_04_Fmap.png
# 025_05_Fmap.png
# 025_06_Fmap.png
# 025_07_Fmap.png
# 025_08_Fmap.png
# 025_09_Fmap.png
# 025_10_Fmap.png
# 025_11_Fmap.png
# 025_12_Fmap.png
# 025_13_Fmap.png
# 025_14_Fmap.png
# 025_15_Fmap.png
# 026_00_Fmap.png
# 026_01_Fmap.png
# 026_02_Fmap.png
# 026_03_Fmap.png
# 026_04_Fmap.png
# 026_05_Fmap.png
# 026_06_Fmap.png
# 026_07_Fmap.png
# 026_08_Fmap.png
# 026_09_Fmap.png
# 026_10_Fmap.png
# 026_11_Fmap.png
# 026_12_Fmap.png
# 026_13_Fmap.png
# 026_14_Fmap.png
# 026_15_Fmap.png
# 027_00_Fmap.png
# 027_01_Fmap.png
# 027_02_Fmap.png
# 027_03_Fmap.png
# 027_04_Fmap.png
# 027_05_Fmap.png
# 027_06_Fmap.png
# 027_07_Fmap.png
# 027_08_Fmap.png
# 027_09_Fmap.png
# 027_10_Fmap.png
# 027_11_Fmap.png
# 027_12_Fmap.png
# 027_13_Fmap.png
# 027_14_Fmap.png
# 027_15_Fmap.png
# 028_00_Fmap.png
# 028_01_Fmap.png
# 028_02_Fmap.png
# 028_03_Fmap.png
# 028_04_Fmap.png
# 028_05_Fmap.png
# 028_06_Fmap.png
# 028_07_Fmap.png
# 028_08_Fmap.png
# 028_09_Fmap.png
# 028_10_Fmap.png
# 028_11_Fmap.png
# 028_12_Fmap.png
# 028_13_Fmap.png
# 028_14_Fmap.png
# 028_15_Fmap.png
# 029_00_Fmap.png
# 029_01_Fmap.png
# 029_02_Fmap.png
# 029_03_Fmap.png
# 029_04_Fmap.png
# 029_05_Fmap.png
# 029_06_Fmap.png
# 029_07_Fmap.png
# 029_08_Fmap.png
# 029_09_Fmap.png
# 029_10_Fmap.png
# 029_11_Fmap.png
# 029_12_Fmap.png
# 029_13_Fmap.png
# 029_14_Fmap.png
# 029_15_Fmap.png
# 030_00_Fmap.png
# 030_01_Fmap.png
# 030_02_Fmap.png
# 030_03_Fmap.png
# 030_04_Fmap.png
# 030_05_Fmap.png
# 030_06_Fmap.png
# 030_07_Fmap.png
# 030_08_Fmap.png
# 030_09_Fmap.png
# 030_10_Fmap.png
# 030_11_Fmap.png
# 030_12_Fmap.png
# 030_13_Fmap.png
# 030_14_Fmap.png
# 030_15_Fmap.png
# 031_00_Fmap.png
# 031_01_Fmap.png
# 031_02_Fmap.png
# 031_03_Fmap.png
# 031_04_Fmap.png
# 031_05_Fmap.png
# 031_06_Fmap.png
# 031_07_Fmap.png
# 031_08_Fmap.png
# 031_09_Fmap.png
# 031_10_Fmap.png
# 031_11_Fmap.png
# 031_12_Fmap.png
# 031_13_Fmap.png
# 031_14_Fmap.png
# 031_15_Fmap.png
# 032_00_Fmap.png
# 032_01_Fmap.png
# 032_02_Fmap.png
# 032_03_Fmap.png
# 032_04_Fmap.png
# 032_05_Fmap.png
# 032_06_Fmap.png
# 032_07_Fmap.png
# 032_08_Fmap.png
# 032_09_Fmap.png
# 032_10_Fmap.png
# 032_11_Fmap.png
# 032_12_Fmap.png
# 032_13_Fmap.png
# 032_14_Fmap.png
# 032_15_Fmap.png
# 033_00_Fmap.png
# 033_01_Fmap.png
# 033_02_Fmap.png
# 033_03_Fmap.png
# 033_04_Fmap.png
# 033_05_Fmap.png
# 033_06_Fmap.png
# 033_07_Fmap.png
# 033_08_Fmap.png
# 033_09_Fmap.png
# 033_10_Fmap.png
# 033_11_Fmap.png
# 033_12_Fmap.png
# 033_13_Fmap.png
# 033_14_Fmap.png
# 033_15_Fmap.png
# 034_00_Fmap.png
# 034_01_Fmap.png
# 034_02_Fmap.png
# 034_03_Fmap.png
# 034_04_Fmap.png
# 034_05_Fmap.png
# 034_06_Fmap.png
# 034_07_Fmap.png
# 034_08_Fmap.png
# 034_09_Fmap.png
# 034_10_Fmap.png
# 034_11_Fmap.png
# 034_12_Fmap.png
# 034_13_Fmap.png
# 034_14_Fmap.png
# 034_15_Fmap.png
# 035_00_Fmap.png
# 035_01_Fmap.png
# 035_02_Fmap.png
# 035_03_Fmap.png
# 035_04_Fmap.png
# 035_05_Fmap.png
# 035_06_Fmap.png
# 035_07_Fmap.png
# 035_08_Fmap.png
# 035_09_Fmap.png
# 035_10_Fmap.png
# 035_11_Fmap.png
# 035_12_Fmap.png
# 035_13_Fmap.png
# 035_14_Fmap.png
# 035_15_Fmap.png
# 036_00_Fmap.png
# 036_01_Fmap.png
# 036_02_Fmap.png
# 036_03_Fmap.png
# 036_04_Fmap.png
# 036_05_Fmap.png
# 036_06_Fmap.png
# 036_07_Fmap.png
# 036_08_Fmap.png
# 036_09_Fmap.png
# 036_10_Fmap.png
# 036_11_Fmap.png
# 036_12_Fmap.png
# 036_13_Fmap.png
# 036_14_Fmap.png
# 036_15_Fmap.png
# 037_00_Fmap.png
# 037_01_Fmap.png
# 037_02_Fmap.png
# 037_03_Fmap.png
# 037_04_Fmap.png
# 037_05_Fmap.png
# 037_06_Fmap.png
# 037_07_Fmap.png
# 037_08_Fmap.png
# 037_09_Fmap.png
# 037_10_Fmap.png
# 037_11_Fmap.png
# 037_12_Fmap.png
# 037_13_Fmap.png
# 037_14_Fmap.png
# 037_15_Fmap.png
# 038_00_Fmap.png
# 038_01_Fmap.png
# 038_02_Fmap.png
# 038_03_Fmap.png
# 038_04_Fmap.png
# 038_05_Fmap.png
# 038_06_Fmap.png
# 038_07_Fmap.png
# 038_08_Fmap.png
# 038_09_Fmap.png
# 038_10_Fmap.png
# 038_11_Fmap.png
# 038_12_Fmap.png
# 038_13_Fmap.png
# 038_14_Fmap.png
# 038_15_Fmap.png
# 039_00_Fmap.png
# 039_01_Fmap.png
# 039_02_Fmap.png
# 039_03_Fmap.png
# 039_04_Fmap.png
# 039_05_Fmap.png
# 039_06_Fmap.png
# 039_07_Fmap.png
# 039_08_Fmap.png
# 039_09_Fmap.png
# 039_10_Fmap.png
# 039_11_Fmap.png
# 039_12_Fmap.png
# 039_13_Fmap.png
# 039_14_Fmap.png
# 039_15_Fmap.png
# 040_00_Fmap.png
# 040_01_Fmap.png
# 040_02_Fmap.png
# 040_03_Fmap.png
# 040_04_Fmap.png
# 040_05_Fmap.png
# 040_06_Fmap.png
# 040_07_Fmap.png
# 040_08_Fmap.png
# 040_09_Fmap.png
# 040_10_Fmap.png
# 040_11_Fmap.png
# 040_12_Fmap.png
# 040_13_Fmap.png
# 040_14_Fmap.png
# 040_15_Fmap.png
# 041_00_Fmap.png
# 041_01_Fmap.png
# 041_02_Fmap.png
# 041_03_Fmap.png
# 041_04_Fmap.png
# 041_05_Fmap.png
# 041_06_Fmap.png
# 041_07_Fmap.png
# 041_08_Fmap.png
# 041_09_Fmap.png
# 041_10_Fmap.png
# 041_11_Fmap.png
# 041_12_Fmap.png
# 041_13_Fmap.png
# 041_14_Fmap.png
# 041_15_Fmap.png
# 042_00_Fmap.png
# 042_01_Fmap.png
# 042_02_Fmap.png
# 042_03_Fmap.png
# 042_04_Fmap.png
# 042_05_Fmap.png
# 042_06_Fmap.png
# 042_07_Fmap.png
# 042_08_Fmap.png
# 042_09_Fmap.png
# 042_10_Fmap.png
# 042_11_Fmap.png
# 042_12_Fmap.png
# 042_13_Fmap.png
# 042_14_Fmap.png
# 042_15_Fmap.png
# 043_00_Fmap.png
# 043_01_Fmap.png
# 043_02_Fmap.png
# 043_03_Fmap.png
# 043_04_Fmap.png
# 043_05_Fmap.png
# 043_06_Fmap.png
# 043_07_Fmap.png
# 043_08_Fmap.png
# 043_09_Fmap.png
# 043_10_Fmap.png
# 043_11_Fmap.png
# 043_12_Fmap.png
# 043_13_Fmap.png
# 043_14_Fmap.png
# 043_15_Fmap.png
# 044_00_Fmap.png
# 044_01_Fmap.png
# 044_02_Fmap.png
# 044_03_Fmap.png
# 044_04_Fmap.png
# 044_05_Fmap.png
# 044_06_Fmap.png
# 044_07_Fmap.png
# 044_08_Fmap.png
# 044_09_Fmap.png
# 044_10_Fmap.png
# 044_11_Fmap.png
# 044_12_Fmap.png
# 044_13_Fmap.png
# 044_14_Fmap.png
# 044_15_Fmap.png
# 045_00_Fmap.png
# 045_01_Fmap.png
# 045_02_Fmap.png
# 045_03_Fmap.png
# 045_04_Fmap.png
# 045_05_Fmap.png
# 045_06_Fmap.png
# 045_07_Fmap.png
# 045_08_Fmap.png
# 045_09_Fmap.png
# 045_10_Fmap.png
# 045_11_Fmap.png
# 045_12_Fmap.png
# 045_13_Fmap.png
# 045_14_Fmap.png
# 045_15_Fmap.png
# 046_00_Fmap.png
# 046_01_Fmap.png
# 046_02_Fmap.png
# 046_03_Fmap.png
# 046_04_Fmap.png
# 046_05_Fmap.png
# 046_06_Fmap.png
# 046_07_Fmap.png
# 046_08_Fmap.png
# 046_09_Fmap.png
# 046_10_Fmap.png
# 046_11_Fmap.png
# 046_12_Fmap.png
# 046_13_Fmap.png
# 046_14_Fmap.png
# 046_15_Fmap.png
# 047_00_Fmap.png
# 047_01_Fmap.png
# 047_02_Fmap.png
# 047_03_Fmap.png
# 047_04_Fmap.png
# 047_05_Fmap.png
# 047_06_Fmap.png
# 047_07_Fmap.png
# 047_08_Fmap.png
# 047_09_Fmap.png
# 047_10_Fmap.png
# 047_11_Fmap.png
# 047_12_Fmap.png
# 047_13_Fmap.png
# 047_14_Fmap.png
# 047_15_Fmap.png
# 048_00_Fmap.png
# 048_01_Fmap.png
# 048_02_Fmap.png
# 048_03_Fmap.png
# 048_04_Fmap.png
# 048_05_Fmap.png
# 048_06_Fmap.png
# 048_07_Fmap.png
# 048_08_Fmap.png
# 048_09_Fmap.png
# 048_10_Fmap.png
# 048_11_Fmap.png
# 048_12_Fmap.png
# 048_13_Fmap.png
# 048_14_Fmap.png
# 048_15_Fmap.png
# 049_00_Fmap.png
# 049_01_Fmap.png
# 049_02_Fmap.png
# 049_03_Fmap.png
# 049_04_Fmap.png
# 049_05_Fmap.png
# 049_06_Fmap.png
# 049_07_Fmap.png
# 049_08_Fmap.png
# 049_09_Fmap.png
# 049_10_Fmap.png
# 049_11_Fmap.png
# 049_12_Fmap.png
# 049_13_Fmap.png
# 049_14_Fmap.png
# 049_15_Fmap.png
# 050_00_Fmap.png
# 050_01_Fmap.png
# 050_02_Fmap.png
# 050_03_Fmap.png
# 050_04_Fmap.png
# 050_05_Fmap.png
# 050_06_Fmap.png
# 050_07_Fmap.png
# 050_08_Fmap.png
# 050_09_Fmap.png
# 050_10_Fmap.png
# 050_11_Fmap.png
# 050_12_Fmap.png
# 050_13_Fmap.png
# 050_14_Fmap.png
# 050_15_Fmap.png
# 051_00_Fmap.png
# 051_01_Fmap.png
# 051_02_Fmap.png
# 051_03_Fmap.png
# 051_04_Fmap.png
# 051_05_Fmap.png
# 051_06_Fmap.png
# 051_07_Fmap.png
# 051_08_Fmap.png
# 051_09_Fmap.png
# 051_10_Fmap.png
# 051_11_Fmap.png
# 051_12_Fmap.png
# 051_13_Fmap.png
# 051_14_Fmap.png
# 051_15_Fmap.png
# 052_00_Fmap.png
# 052_01_Fmap.png
# 052_02_Fmap.png
# 052_03_Fmap.png
# 052_04_Fmap.png
# 052_05_Fmap.png
# 052_06_Fmap.png
# 052_07_Fmap.png
# 052_08_Fmap.png
# 052_09_Fmap.png
# 052_10_Fmap.png
# 052_11_Fmap.png
# 052_12_Fmap.png
# 052_13_Fmap.png
# 052_14_Fmap.png
# 052_15_Fmap.png
# 053_00_Fmap.png
# 053_01_Fmap.png
# 053_02_Fmap.png
# 053_03_Fmap.png
# 053_04_Fmap.png
# 053_05_Fmap.png
# 053_06_Fmap.png
# 053_07_Fmap.png
# 053_08_Fmap.png
# 053_09_Fmap.png
# 053_10_Fmap.png
# 053_11_Fmap.png
# 053_12_Fmap.png
# 053_13_Fmap.png
# 053_14_Fmap.png
# 053_15_Fmap.png
# 054_00_Fmap.png
# 054_01_Fmap.png
# 054_02_Fmap.png
# 054_03_Fmap.png
# 054_04_Fmap.png
# 054_05_Fmap.png
# 054_06_Fmap.png
# 054_07_Fmap.png
# 054_08_Fmap.png
# 054_09_Fmap.png
# 054_10_Fmap.png
# 054_11_Fmap.png
# 054_12_Fmap.png
# 054_13_Fmap.png
# 054_14_Fmap.png
# 054_15_Fmap.png
# 055_00_Fmap.png
# 055_01_Fmap.png
# 055_02_Fmap.png
# 055_03_Fmap.png
# 055_04_Fmap.png
# 055_05_Fmap.png
# 055_06_Fmap.png
# 055_07_Fmap.png
# 055_08_Fmap.png
# 055_09_Fmap.png
# 055_10_Fmap.png
# 055_11_Fmap.png
# 055_12_Fmap.png
# 055_13_Fmap.png
# 055_14_Fmap.png
# 055_15_Fmap.png
# 056_00_Fmap.png
# 056_01_Fmap.png
# 056_02_Fmap.png
# 056_03_Fmap.png
# 056_04_Fmap.png
# 056_05_Fmap.png
# 056_06_Fmap.png
# 056_07_Fmap.png
# 056_08_Fmap.png
# 056_09_Fmap.png
# 056_10_Fmap.png
# 056_11_Fmap.png
# 056_12_Fmap.png
# 056_13_Fmap.png
# 056_14_Fmap.png
# 056_15_Fmap.png
# 057_00_Fmap.png
# 057_01_Fmap.png
# 057_02_Fmap.png
# 057_03_Fmap.png
# 057_04_Fmap.png
# 057_05_Fmap.png
# 057_06_Fmap.png
# 057_07_Fmap.png
# 057_08_Fmap.png
# 057_09_Fmap.png
# 057_10_Fmap.png
# 057_11_Fmap.png
# 057_12_Fmap.png
# 057_13_Fmap.png
# 057_14_Fmap.png
# 057_15_Fmap.png
# 058_00_Fmap.png
# 058_01_Fmap.png
# 058_02_Fmap.png
# 058_03_Fmap.png
# 058_04_Fmap.png
# 058_05_Fmap.png
# 058_06_Fmap.png
# 058_07_Fmap.png
# 058_08_Fmap.png
# 058_09_Fmap.png
# 058_10_Fmap.png
# 058_11_Fmap.png
# 058_12_Fmap.png
# 058_13_Fmap.png
# 058_14_Fmap.png
# 058_15_Fmap.png
# 059_00_Fmap.png
# 059_01_Fmap.png
# 059_02_Fmap.png
# 059_03_Fmap.png
# 059_04_Fmap.png
# 059_05_Fmap.png
# 059_06_Fmap.png
# 059_07_Fmap.png
# 059_08_Fmap.png
# 059_09_Fmap.png
# 059_10_Fmap.png
# 059_11_Fmap.png
# 059_12_Fmap.png
# 059_13_Fmap.png
# 059_14_Fmap.png
# 059_15_Fmap.png
# 060_00_Fmap.png
# 060_01_Fmap.png
# 060_02_Fmap.png
# 060_03_Fmap.png
# 060_04_Fmap.png
# 060_05_Fmap.png
# 060_06_Fmap.png
# 060_07_Fmap.png
# 060_08_Fmap.png
# 060_09_Fmap.png
# 060_10_Fmap.png
# 060_11_Fmap.png
# 060_12_Fmap.png
# 060_13_Fmap.png
# 060_14_Fmap.png
# 060_15_Fmap.png
# 061_00_Fmap.png
# 061_01_Fmap.png
# 061_02_Fmap.png
# 061_03_Fmap.png
# 061_04_Fmap.png
# 061_05_Fmap.png
# 061_06_Fmap.png
# 061_07_Fmap.png
# 061_08_Fmap.png
# 061_09_Fmap.png
# 061_10_Fmap.png
# 061_11_Fmap.png
# 061_12_Fmap.png
# 061_13_Fmap.png
# 061_14_Fmap.png
# 061_15_Fmap.png
# 062_00_Fmap.png
# 062_01_Fmap.png
# 062_02_Fmap.png
# 062_03_Fmap.png
# 062_04_Fmap.png
# 062_05_Fmap.png
# 062_06_Fmap.png
# 062_07_Fmap.png
# 062_08_Fmap.png
# 062_09_Fmap.png
# 062_10_Fmap.png
# 062_11_Fmap.png
# 062_12_Fmap.png
# 062_13_Fmap.png
# 062_14_Fmap.png
# 062_15_Fmap.png
# 063_00_Fmap.png
# 063_01_Fmap.png
# 063_02_Fmap.png
# 063_03_Fmap.png
# 063_04_Fmap.png
# 063_05_Fmap.png
# 063_06_Fmap.png
# 063_07_Fmap.png
# 063_08_Fmap.png
# 063_09_Fmap.png
# 063_10_Fmap.png
# 063_11_Fmap.png
# 063_12_Fmap.png
# 063_13_Fmap.png
# 063_14_Fmap.png
# 063_15_Fmap.png
# 064_00_Fmap.png
# 064_01_Fmap.png
# 064_02_Fmap.png
# 064_03_Fmap.png
# 064_04_Fmap.png
# 064_05_Fmap.png
# 064_06_Fmap.png
# 064_07_Fmap.png
# 064_08_Fmap.png
# 064_09_Fmap.png
# 064_10_Fmap.png
# 064_11_Fmap.png
# 064_12_Fmap.png
# 064_13_Fmap.png
# 064_14_Fmap.png
# 064_15_Fmap.png
# 065_00_Fmap.png
# 065_01_Fmap.png
# 065_02_Fmap.png
# 065_03_Fmap.png
# 065_04_Fmap.png
# 065_05_Fmap.png
# 065_06_Fmap.png
# 065_07_Fmap.png
# 065_08_Fmap.png
# 065_09_Fmap.png
# 065_10_Fmap.png
# 065_11_Fmap.png
# 065_12_Fmap.png
# 065_13_Fmap.png
# 065_14_Fmap.png
# 065_15_Fmap.png
# 066_00_Fmap.png
# 066_01_Fmap.png
# 066_02_Fmap.png
# 066_03_Fmap.png
# 066_04_Fmap.png
# 066_05_Fmap.png
# 066_06_Fmap.png
# 066_07_Fmap.png
# 066_08_Fmap.png
# 066_09_Fmap.png
# 066_10_Fmap.png
# 066_11_Fmap.png
# 066_12_Fmap.png
# 066_13_Fmap.png
# 066_14_Fmap.png
# 066_15_Fmap.png
# 067_00_Fmap.png
# 067_01_Fmap.png
# 067_02_Fmap.png
# 067_03_Fmap.png
# 067_04_Fmap.png
# 067_05_Fmap.png
# 067_06_Fmap.png
# 067_07_Fmap.png
# 067_08_Fmap.png
# 067_09_Fmap.png
# 067_10_Fmap.png
# 067_11_Fmap.png
# 067_12_Fmap.png
# 067_13_Fmap.png
# 067_14_Fmap.png
# 067_15_Fmap.png
# 068_00_Fmap.png
# 068_01_Fmap.png
# 068_02_Fmap.png
# 068_03_Fmap.png
# 068_04_Fmap.png
# 068_05_Fmap.png
# 068_06_Fmap.png
# 068_07_Fmap.png
# 068_08_Fmap.png
# 068_09_Fmap.png
# 068_10_Fmap.png
# 068_11_Fmap.png
# 068_12_Fmap.png
# 068_13_Fmap.png
# 068_14_Fmap.png
# 068_15_Fmap.png
# 069_00_Fmap.png
# 069_01_Fmap.png
# 069_02_Fmap.png
# 069_03_Fmap.png
# 069_04_Fmap.png
# 069_05_Fmap.png
# 069_06_Fmap.png
# 069_07_Fmap.png
# 069_08_Fmap.png
# 069_09_Fmap.png
# 069_10_Fmap.png
# 069_11_Fmap.png
# 069_12_Fmap.png
# 069_13_Fmap.png
# 069_14_Fmap.png
# 069_15_Fmap.png
# 070_00_Fmap.png
# 070_01_Fmap.png
# 070_02_Fmap.png
# 070_03_Fmap.png
# 070_04_Fmap.png
# 070_05_Fmap.png
# 070_06_Fmap.png
# 070_07_Fmap.png
# 070_08_Fmap.png
# 070_09_Fmap.png
# 070_10_Fmap.png
# 070_11_Fmap.png
# 070_12_Fmap.png
# 070_13_Fmap.png
# 070_14_Fmap.png
# 070_15_Fmap.png
# 071_00_Fmap.png
# 071_01_Fmap.png
# 071_02_Fmap.png
# 071_03_Fmap.png
# 071_04_Fmap.png
# 071_05_Fmap.png
# 071_06_Fmap.png
# 071_07_Fmap.png
# 071_08_Fmap.png
# 071_09_Fmap.png
# 071_10_Fmap.png
# 071_11_Fmap.png
# 071_12_Fmap.png
# 071_13_Fmap.png
# 071_14_Fmap.png
# 071_15_Fmap.png
# 072_00_Fmap.png
# 072_01_Fmap.png
# 072_02_Fmap.png
# 072_03_Fmap.png
# 072_04_Fmap.png
# 072_05_Fmap.png
# 072_06_Fmap.png
# 072_07_Fmap.png
# 072_08_Fmap.png
# 072_09_Fmap.png
# 072_10_Fmap.png
# 072_11_Fmap.png
# 072_12_Fmap.png
# 072_13_Fmap.png
# 072_14_Fmap.png
# 072_15_Fmap.png
# 073_00_Fmap.png
# 073_01_Fmap.png
# 073_02_Fmap.png
# 073_03_Fmap.png
# 073_04_Fmap.png
# 073_05_Fmap.png
# 073_06_Fmap.png
# 073_07_Fmap.png
# 073_08_Fmap.png
# 073_09_Fmap.png
# 073_10_Fmap.png
# 073_11_Fmap.png
# 073_12_Fmap.png
# 073_13_Fmap.png
# 073_14_Fmap.png
# 073_15_Fmap.png
# 074_00_Fmap.png
# 074_01_Fmap.png
# 074_02_Fmap.png
# 074_03_Fmap.png
# 074_04_Fmap.png
# 074_05_Fmap.png
# 074_06_Fmap.png
# 074_07_Fmap.png
# 074_08_Fmap.png
# 074_09_Fmap.png
# 074_10_Fmap.png
# 074_11_Fmap.png
# 074_12_Fmap.png
# 074_13_Fmap.png
# 074_14_Fmap.png
# 074_15_Fmap.png
# 075_00_Fmap.png
# 075_01_Fmap.png
# 075_02_Fmap.png
# 075_03_Fmap.png
# 075_04_Fmap.png
# 075_05_Fmap.png
# 075_06_Fmap.png
# 075_07_Fmap.png
# 075_08_Fmap.png
# 075_09_Fmap.png
# 075_10_Fmap.png
# 075_11_Fmap.png
# 075_12_Fmap.png
# 075_13_Fmap.png
# 075_14_Fmap.png
# 075_15_Fmap.png
# 076_00_Fmap.png
# 076_01_Fmap.png
# 076_02_Fmap.png
# 076_03_Fmap.png
# 076_04_Fmap.png
# 076_05_Fmap.png
# 076_06_Fmap.png
# 076_07_Fmap.png
# 076_08_Fmap.png
# 076_09_Fmap.png
# 076_10_Fmap.png
# 076_11_Fmap.png
# 076_12_Fmap.png
# 076_13_Fmap.png
# 076_14_Fmap.png
# 076_15_Fmap.png
# 077_00_Fmap.png
# 077_01_Fmap.png
# 077_02_Fmap.png
# 077_03_Fmap.png
# 077_04_Fmap.png
# 077_05_Fmap.png
# 077_06_Fmap.png
# 077_07_Fmap.png
# 077_08_Fmap.png
# 077_09_Fmap.png
# 077_10_Fmap.png
# 077_11_Fmap.png
# 077_12_Fmap.png
# 077_13_Fmap.png
# 077_14_Fmap.png
# 077_15_Fmap.png
# 078_00_Fmap.png
# 078_01_Fmap.png
# 078_02_Fmap.png
# 078_03_Fmap.png
# 078_04_Fmap.png
# 078_05_Fmap.png
# 078_06_Fmap.png
# 078_07_Fmap.png
# 078_08_Fmap.png
# 078_09_Fmap.png
# 078_10_Fmap.png
# 078_11_Fmap.png
# 078_12_Fmap.png
# 078_13_Fmap.png
# 078_14_Fmap.png
# 078_15_Fmap.png
# 079_00_Fmap.png
# 079_01_Fmap.png
# 079_02_Fmap.png
# 079_03_Fmap.png
# 079_04_Fmap.png
# 079_05_Fmap.png
# 079_06_Fmap.png
# 079_07_Fmap.png
# 079_08_Fmap.png
# 079_09_Fmap.png
# 079_10_Fmap.png
# 079_11_Fmap.png
# 079_12_Fmap.png
# 079_13_Fmap.png
# 079_14_Fmap.png
# 079_15_Fmap.png
# 080_00_Fmap.png
# 080_01_Fmap.png
# 080_02_Fmap.png
# 080_03_Fmap.png
# 080_04_Fmap.png
# 080_05_Fmap.png
# 080_06_Fmap.png
# 080_07_Fmap.png
# 080_08_Fmap.png
# 080_09_Fmap.png
# 080_10_Fmap.png
# 080_11_Fmap.png
# 080_12_Fmap.png
# 080_13_Fmap.png
# 080_14_Fmap.png
# 080_15_Fmap.png
# 081_00_Fmap.png
# 081_01_Fmap.png
# 081_02_Fmap.png
# 081_03_Fmap.png
# 081_04_Fmap.png
# 081_05_Fmap.png
# 081_06_Fmap.png
# 081_07_Fmap.png
# 081_08_Fmap.png
# 081_09_Fmap.png
# 081_10_Fmap.png
# 081_11_Fmap.png
# 081_12_Fmap.png
# 081_13_Fmap.png
# 081_14_Fmap.png
# 081_15_Fmap.png
# 082_00_Fmap.png
# 082_01_Fmap.png
# 082_02_Fmap.png
# 082_03_Fmap.png
# 082_04_Fmap.png
# 082_05_Fmap.png
# 082_06_Fmap.png
# 082_07_Fmap.png
# 082_08_Fmap.png
# 082_09_Fmap.png
# 082_10_Fmap.png
# 082_11_Fmap.png
# 082_12_Fmap.png
# 082_13_Fmap.png
# 082_14_Fmap.png
# 082_15_Fmap.png
# 083_00_Fmap.png
# 083_01_Fmap.png
# 083_02_Fmap.png
# 083_03_Fmap.png
# 083_04_Fmap.png
# 083_05_Fmap.png
# 083_06_Fmap.png
# 083_07_Fmap.png
# 083_08_Fmap.png
# 083_09_Fmap.png
# 083_10_Fmap.png
# 083_11_Fmap.png
# 083_12_Fmap.png
# 083_13_Fmap.png
# 083_14_Fmap.png
# 083_15_Fmap.png
# 084_00_Fmap.png
# 084_01_Fmap.png
# 084_02_Fmap.png
# 084_03_Fmap.png
# 084_04_Fmap.png
# 084_05_Fmap.png
# 084_06_Fmap.png
# 084_07_Fmap.png
# 084_08_Fmap.png
# 084_09_Fmap.png
# 084_10_Fmap.png
# 084_11_Fmap.png
# 084_12_Fmap.png
# 084_13_Fmap.png
# 084_14_Fmap.png
# 084_15_Fmap.png
# 085_00_Fmap.png
# 085_01_Fmap.png
# 085_02_Fmap.png
# 085_03_Fmap.png
# 085_04_Fmap.png
# 085_05_Fmap.png
# 085_06_Fmap.png
# 085_07_Fmap.png
# 085_08_Fmap.png
# 085_09_Fmap.png
# 085_10_Fmap.png
# 085_11_Fmap.png
# 085_12_Fmap.png
# 085_13_Fmap.png
# 085_14_Fmap.png
# 085_15_Fmap.png
# 086_00_Fmap.png
# 086_01_Fmap.png
# 086_02_Fmap.png
# 086_03_Fmap.png
# 086_04_Fmap.png
# 086_05_Fmap.png
# 086_06_Fmap.png
# 086_07_Fmap.png
# 086_08_Fmap.png
# 086_09_Fmap.png
# 086_10_Fmap.png
# 086_11_Fmap.png
# 086_12_Fmap.png
# 086_13_Fmap.png
# 086_14_Fmap.png
# 086_15_Fmap.png
# 087_00_Fmap.png
# 087_01_Fmap.png
# 087_02_Fmap.png
# 087_03_Fmap.png
# 087_04_Fmap.png
# 087_05_Fmap.png
# 087_06_Fmap.png
# 087_07_Fmap.png
# 087_08_Fmap.png
# 087_09_Fmap.png
# 087_10_Fmap.png
# 087_11_Fmap.png
# 087_12_Fmap.png
# 087_13_Fmap.png
# 087_14_Fmap.png
# 087_15_Fmap.png
# 088_00_Fmap.png
# 088_01_Fmap.png
# 088_02_Fmap.png
# 088_03_Fmap.png
# 088_04_Fmap.png
# 088_05_Fmap.png
# 088_06_Fmap.png
# 088_07_Fmap.png
# 088_08_Fmap.png
# 088_09_Fmap.png
# 088_10_Fmap.png
# 088_11_Fmap.png
# 088_12_Fmap.png
# 088_13_Fmap.png
# 088_14_Fmap.png
# 088_15_Fmap.png
# 089_00_Fmap.png
# 089_01_Fmap.png
# 089_02_Fmap.png
# 089_03_Fmap.png
# 089_04_Fmap.png
# 089_05_Fmap.png
# 089_06_Fmap.png
# 089_07_Fmap.png
# 089_08_Fmap.png
# 089_09_Fmap.png
# 089_10_Fmap.png
# 089_11_Fmap.png
# 089_12_Fmap.png
# 089_13_Fmap.png
# 089_14_Fmap.png
# 089_15_Fmap.png
# 090_00_Fmap.png
# 090_01_Fmap.png
# 090_02_Fmap.png
# 090_03_Fmap.png
# 090_04_Fmap.png
# 090_05_Fmap.png
# 090_06_Fmap.png
# 090_07_Fmap.png
# 090_08_Fmap.png
# 090_09_Fmap.png
# 090_10_Fmap.png
# 090_11_Fmap.png
# 090_12_Fmap.png
# 090_13_Fmap.png
# 090_14_Fmap.png
# 090_15_Fmap.png
# 091_00_Fmap.png
# 091_01_Fmap.png
# 091_02_Fmap.png
# 091_03_Fmap.png
# 091_04_Fmap.png
# 091_05_Fmap.png
# 091_06_Fmap.png
# 091_07_Fmap.png
# 091_08_Fmap.png
# 091_09_Fmap.png
# 091_10_Fmap.png
# 091_11_Fmap.png
# 091_12_Fmap.png
# 091_13_Fmap.png
# 091_14_Fmap.png
# 091_15_Fmap.png
# 092_00_Fmap.png
# 092_01_Fmap.png
# 092_02_Fmap.png
# 092_03_Fmap.png
# 092_04_Fmap.png
# 092_05_Fmap.png
# 092_06_Fmap.png
# 092_07_Fmap.png
# 092_08_Fmap.png
# 092_09_Fmap.png
# 092_10_Fmap.png
# 092_11_Fmap.png
# 092_12_Fmap.png
# 092_13_Fmap.png
# 092_14_Fmap.png
# 092_15_Fmap.png
# 093_00_Fmap.png
# 093_01_Fmap.png
# 093_02_Fmap.png
# 093_03_Fmap.png
# 093_04_Fmap.png
# 093_05_Fmap.png
# 093_06_Fmap.png
# 093_07_Fmap.png
# 093_08_Fmap.png
# 093_09_Fmap.png
# 093_10_Fmap.png
# 093_11_Fmap.png
# 093_12_Fmap.png
# 093_13_Fmap.png
# 093_14_Fmap.png
# 093_15_Fmap.png
# 094_00_Fmap.png
# 094_01_Fmap.png
# 094_02_Fmap.png
# 094_03_Fmap.png
# 094_04_Fmap.png
# 094_05_Fmap.png
# 094_06_Fmap.png
# 094_07_Fmap.png
# 094_08_Fmap.png
# 094_09_Fmap.png
# 094_10_Fmap.png
# 094_11_Fmap.png
# 094_12_Fmap.png
# 094_13_Fmap.png
# 094_14_Fmap.png
# 094_15_Fmap.png
# 095_00_Fmap.png
# 095_01_Fmap.png
# 095_02_Fmap.png
# 095_03_Fmap.png
# 095_04_Fmap.png
# 095_05_Fmap.png
# 095_06_Fmap.png
# 095_07_Fmap.png
# 095_08_Fmap.png
# 095_09_Fmap.png
# 095_10_Fmap.png
# 095_11_Fmap.png
# 095_12_Fmap.png
# 095_13_Fmap.png
# 095_14_Fmap.png
# 095_15_Fmap.png
# 096_00_Fmap.png
# 096_01_Fmap.png
# 096_02_Fmap.png
# 096_03_Fmap.png
# 096_04_Fmap.png
# 096_05_Fmap.png
# 096_06_Fmap.png
# 096_07_Fmap.png
# 096_08_Fmap.png
# 096_09_Fmap.png
# 096_10_Fmap.png
# 096_11_Fmap.png
# 096_12_Fmap.png
# 096_13_Fmap.png
# 096_14_Fmap.png
# 096_15_Fmap.png
# 097_00_Fmap.png
# 097_01_Fmap.png
# 097_02_Fmap.png
# 097_03_Fmap.png
# 097_04_Fmap.png
# 097_05_Fmap.png
# 097_06_Fmap.png
# 097_07_Fmap.png
# 097_08_Fmap.png
# 097_09_Fmap.png
# 097_10_Fmap.png
# 097_11_Fmap.png
# 097_12_Fmap.png
# 097_13_Fmap.png
# 097_14_Fmap.png
# 097_15_Fmap.png
# 098_00_Fmap.png
# 098_01_Fmap.png
# 098_02_Fmap.png
# 098_03_Fmap.png
# 098_04_Fmap.png
# 098_05_Fmap.png
# 098_06_Fmap.png
# 098_07_Fmap.png
# 098_08_Fmap.png
# 098_09_Fmap.png
# 098_10_Fmap.png
# 098_11_Fmap.png
# 098_12_Fmap.png
# 098_13_Fmap.png
# 098_14_Fmap.png
# 098_15_Fmap.png
# 099_00_Fmap.png
# 099_01_Fmap.png
# 099_02_Fmap.png
# 099_03_Fmap.png
# 099_04_Fmap.png
# 099_05_Fmap.png
# 099_06_Fmap.png
# 099_07_Fmap.png
# 099_08_Fmap.png
# 099_09_Fmap.png
# 099_10_Fmap.png
# 099_11_Fmap.png
# 099_12_Fmap.png
# 099_13_Fmap.png
# 099_14_Fmap.png
# 099_15_Fmap.png
# 100_00_Fmap.png
# 100_01_Fmap.png
# 100_02_Fmap.png
# 100_03_Fmap.png
# 100_04_Fmap.png
# 100_05_Fmap.png
# 100_06_Fmap.png
# 100_07_Fmap.png
# 100_08_Fmap.png
# 100_09_Fmap.png
# 100_10_Fmap.png
# 100_11_Fmap.png
# 100_12_Fmap.png
# 100_13_Fmap.png
# 100_14_Fmap.png
# 100_15_Fmap.png
# 101_00_Fmap.png
# 101_01_Fmap.png
# 101_02_Fmap.png
# 101_03_Fmap.png
# 101_04_Fmap.png
# 101_05_Fmap.png
# 101_06_Fmap.png
# 101_07_Fmap.png
# 101_08_Fmap.png
# 101_09_Fmap.png
# 101_10_Fmap.png
# 101_11_Fmap.png
# 101_12_Fmap.png
# 101_13_Fmap.png
# 101_14_Fmap.png
# 101_15_Fmap.png
# 102_00_Fmap.png
# 102_01_Fmap.png
# 102_02_Fmap.png
# 102_03_Fmap.png
# 102_04_Fmap.png
# 102_05_Fmap.png
# 102_06_Fmap.png
# 102_07_Fmap.png
# 102_08_Fmap.png
# 102_09_Fmap.png
# 102_10_Fmap.png
# 102_11_Fmap.png
# 102_12_Fmap.png
# 102_13_Fmap.png
# 102_14_Fmap.png
# 102_15_Fmap.png
# 103_00_Fmap.png
# 103_01_Fmap.png
# 103_02_Fmap.png
# 103_03_Fmap.png
# 103_04_Fmap.png
# 103_05_Fmap.png
# 103_06_Fmap.png
# 103_07_Fmap.png
# 103_08_Fmap.png
# 103_09_Fmap.png
# 103_10_Fmap.png
# 103_11_Fmap.png
# 103_12_Fmap.png
# 103_13_Fmap.png
# 103_14_Fmap.png
# 103_15_Fmap.png
# 104_00_Fmap.png
# 104_01_Fmap.png
# 104_02_Fmap.png
# 104_03_Fmap.png
# 104_04_Fmap.png
# 104_05_Fmap.png
# 104_06_Fmap.png
# 104_07_Fmap.png
# 104_08_Fmap.png
# 104_09_Fmap.png
# 104_10_Fmap.png
# 104_11_Fmap.png
# 104_12_Fmap.png
# 104_13_Fmap.png
# 104_14_Fmap.png
# 104_15_Fmap.png
# 105_00_Fmap.png
# 105_01_Fmap.png
# 105_02_Fmap.png
# 105_03_Fmap.png
# 105_04_Fmap.png
# 105_05_Fmap.png
# 105_06_Fmap.png
# 105_07_Fmap.png
# 105_08_Fmap.png
# 105_09_Fmap.png
# 105_10_Fmap.png
# 105_11_Fmap.png
# 105_12_Fmap.png
# 105_13_Fmap.png
# 105_14_Fmap.png
# 105_15_Fmap.png
# 106_00_Fmap.png
# 106_01_Fmap.png
# 106_02_Fmap.png
# 106_03_Fmap.png
# 106_04_Fmap.png
# 106_05_Fmap.png
# 106_06_Fmap.png
# 106_07_Fmap.png
# 106_08_Fmap.png
# 106_09_Fmap.png
# 106_10_Fmap.png
# 106_11_Fmap.png
# 106_12_Fmap.png
# 106_13_Fmap.png
# 106_14_Fmap.png
# 106_15_Fmap.png
# 107_00_Fmap.png
# 107_01_Fmap.png
# 107_02_Fmap.png
# 107_03_Fmap.png
# 107_04_Fmap.png
# 107_05_Fmap.png
# 107_06_Fmap.png
# 107_07_Fmap.png
# 107_08_Fmap.png
# 107_09_Fmap.png
# 107_10_Fmap.png
# 107_11_Fmap.png
# 107_12_Fmap.png
# 107_13_Fmap.png
# 107_14_Fmap.png
# 107_15_Fmap.png
# 108_00_Fmap.png
# 108_01_Fmap.png
# 108_02_Fmap.png
# 108_03_Fmap.png
# 108_04_Fmap.png
# 108_05_Fmap.png
# 108_06_Fmap.png
# 108_07_Fmap.png
# 108_08_Fmap.png
# 108_09_Fmap.png
# 108_10_Fmap.png
# 108_11_Fmap.png
# 108_12_Fmap.png
# 108_13_Fmap.png
# 108_14_Fmap.png
# 108_15_Fmap.png
# 109_00_Fmap.png
# 109_01_Fmap.png
# 109_02_Fmap.png
# 109_03_Fmap.png
# 109_04_Fmap.png
# 109_05_Fmap.png
# 109_06_Fmap.png
# 109_07_Fmap.png
# 109_08_Fmap.png
# 109_09_Fmap.png
# 109_10_Fmap.png
# 109_11_Fmap.png
# 109_12_Fmap.png
# 109_13_Fmap.png
# 109_14_Fmap.png
# 109_15_Fmap.png
# 110_00_Fmap.png
# 110_01_Fmap.png
# 110_02_Fmap.png
# 110_03_Fmap.png
# 110_04_Fmap.png
# 110_05_Fmap.png
# 110_06_Fmap.png
# 110_07_Fmap.png
# 110_08_Fmap.png
# 110_09_Fmap.png
# 110_10_Fmap.png
# 110_11_Fmap.png
# 110_12_Fmap.png
# 110_13_Fmap.png
# 110_14_Fmap.png
# 110_15_Fmap.png
# 111_00_Fmap.png
# 111_01_Fmap.png
# 111_02_Fmap.png
# 111_03_Fmap.png
# 111_04_Fmap.png
# 111_05_Fmap.png
# 111_06_Fmap.png
# 111_07_Fmap.png
# 111_08_Fmap.png
# 111_09_Fmap.png
# 111_10_Fmap.png
# 111_11_Fmap.png
# 111_12_Fmap.png
# 111_13_Fmap.png
# 111_14_Fmap.png
# 111_15_Fmap.png
# 112_00_Fmap.png
# 112_01_Fmap.png
# 112_02_Fmap.png
# 112_03_Fmap.png
# 112_04_Fmap.png
# 112_05_Fmap.png
# 112_06_Fmap.png
# 112_07_Fmap.png
# 112_08_Fmap.png
# 112_09_Fmap.png
# 112_10_Fmap.png
# 112_11_Fmap.png
# 112_12_Fmap.png
# 112_13_Fmap.png
# 112_14_Fmap.png
# 112_15_Fmap.png
# 113_00_Fmap.png
# 113_01_Fmap.png
# 113_02_Fmap.png
# 113_03_Fmap.png
# 113_04_Fmap.png
# 113_05_Fmap.png
# 113_06_Fmap.png
# 113_07_Fmap.png
# 113_08_Fmap.png
# 113_09_Fmap.png
# 113_10_Fmap.png
# 113_11_Fmap.png
# 113_12_Fmap.png
# 113_13_Fmap.png
# 113_14_Fmap.png
# 113_15_Fmap.png
# 114_00_Fmap.png
# 114_01_Fmap.png
# 114_02_Fmap.png
# 114_03_Fmap.png
# 114_04_Fmap.png
# 114_05_Fmap.png
# 114_06_Fmap.png
# 114_07_Fmap.png
# 114_08_Fmap.png
# 114_09_Fmap.png
# 114_10_Fmap.png
# 114_11_Fmap.png
# 114_12_Fmap.png
# 114_13_Fmap.png
# 114_14_Fmap.png
# 114_15_Fmap.png
# 115_00_Fmap.png
# 115_01_Fmap.png
# 115_02_Fmap.png
# 115_03_Fmap.png
# 115_04_Fmap.png
# 115_05_Fmap.png
# 115_06_Fmap.png
# 115_07_Fmap.png
# 115_08_Fmap.png
# 115_09_Fmap.png
# 115_10_Fmap.png
# 115_11_Fmap.png
# 115_12_Fmap.png
# 115_13_Fmap.png
# 115_14_Fmap.png
# 115_15_Fmap.png
# 116_00_Fmap.png
# 116_01_Fmap.png
# 116_02_Fmap.png
# 116_03_Fmap.png
# 116_04_Fmap.png
# 116_05_Fmap.png
# 116_06_Fmap.png
# 116_07_Fmap.png
# 116_08_Fmap.png
# 116_09_Fmap.png
# 116_10_Fmap.png
# 116_11_Fmap.png
# 116_12_Fmap.png
# 116_13_Fmap.png
# 116_14_Fmap.png
# 116_15_Fmap.png
# 117_00_Fmap.png
# 117_01_Fmap.png
# 117_02_Fmap.png
# 117_03_Fmap.png
# 117_04_Fmap.png
# 117_05_Fmap.png
# 117_06_Fmap.png
# 117_07_Fmap.png
# 117_08_Fmap.png
# 117_09_Fmap.png
# 117_10_Fmap.png
# 117_11_Fmap.png
# 117_12_Fmap.png
# 117_13_Fmap.png
# 117_14_Fmap.png
# 117_15_Fmap.png
# 118_00_Fmap.png
# 118_01_Fmap.png
# 118_02_Fmap.png
# 118_03_Fmap.png
# 118_04_Fmap.png
# 118_05_Fmap.png
# 118_06_Fmap.png
# 118_07_Fmap.png
# 118_08_Fmap.png
# 118_09_Fmap.png
# 118_10_Fmap.png
# 118_11_Fmap.png
# 118_12_Fmap.png
# 118_13_Fmap.png
# 118_14_Fmap.png
# 118_15_Fmap.png
# 119_00_Fmap.png
# 119_01_Fmap.png
# 119_02_Fmap.png
# 119_03_Fmap.png
# 119_04_Fmap.png
# 119_05_Fmap.png
# 119_06_Fmap.png
# 119_07_Fmap.png
# 119_08_Fmap.png
# 119_09_Fmap.png
# 119_10_Fmap.png
# 119_11_Fmap.png
# 119_12_Fmap.png
# 119_13_Fmap.png
# 119_14_Fmap.png
# 119_15_Fmap.png
# 120_00_Fmap.png
# 120_01_Fmap.png
# 120_02_Fmap.png
# 120_03_Fmap.png
# 120_04_Fmap.png
# 120_05_Fmap.png
# 120_06_Fmap.png
# 120_07_Fmap.png
# 120_08_Fmap.png
# 120_09_Fmap.png
# 120_10_Fmap.png
# 120_11_Fmap.png
# 120_12_Fmap.png
# 120_13_Fmap.png
# 120_14_Fmap.png
# 120_15_Fmap.png
# 121_00_Fmap.png
# 121_01_Fmap.png
# 121_02_Fmap.png
# 121_03_Fmap.png
# 121_04_Fmap.png
# 121_05_Fmap.png
# 121_06_Fmap.png
# 121_07_Fmap.png
# 121_08_Fmap.png
# 121_09_Fmap.png
# 121_10_Fmap.png
# 121_11_Fmap.png
# 121_12_Fmap.png
# 121_13_Fmap.png
# 121_14_Fmap.png
# 121_15_Fmap.png
# 122_00_Fmap.png
# 122_01_Fmap.png
# 122_02_Fmap.png
# 122_03_Fmap.png
# 122_04_Fmap.png
# 122_05_Fmap.png
# 122_06_Fmap.png
# 122_07_Fmap.png
# 122_08_Fmap.png
# 122_09_Fmap.png
# 122_10_Fmap.png
# 122_11_Fmap.png
# 122_12_Fmap.png
# 122_13_Fmap.png
# 122_14_Fmap.png
# 122_15_Fmap.png
# 123_00_Fmap.png
# 123_01_Fmap.png
# 123_02_Fmap.png
# 123_03_Fmap.png
# 123_04_Fmap.png
# 123_05_Fmap.png
# 123_06_Fmap.png
# 123_07_Fmap.png
# 123_08_Fmap.png
# 123_09_Fmap.png
# 123_10_Fmap.png
# 123_11_Fmap.png
# 123_12_Fmap.png
# 123_13_Fmap.png
# 123_14_Fmap.png
# 123_15_Fmap.png
# 124_00_Fmap.png
# 124_01_Fmap.png
# 124_02_Fmap.png
# 124_03_Fmap.png
# 124_04_Fmap.png
# 124_05_Fmap.png
# 124_06_Fmap.png
# 124_07_Fmap.png
# 124_08_Fmap.png
# 124_09_Fmap.png
# 124_10_Fmap.png
# 124_11_Fmap.png
# 124_12_Fmap.png
# 124_13_Fmap.png
# 124_14_Fmap.png
# 124_15_Fmap.png
# 125_00_Fmap.png
# 125_01_Fmap.png
# 125_02_Fmap.png
# 125_03_Fmap.png
# 125_04_Fmap.png
# 125_05_Fmap.png
# 125_06_Fmap.png
# 125_07_Fmap.png
# 125_08_Fmap.png
# 125_09_Fmap.png
# 125_10_Fmap.png
# 125_11_Fmap.png
# 125_12_Fmap.png
# 125_13_Fmap.png
# 125_14_Fmap.png
# 125_15_Fmap.png
# 126_00_Fmap.png
# 126_01_Fmap.png
# 126_02_Fmap.png
# 126_03_Fmap.png
# 126_04_Fmap.png
# 126_05_Fmap.png
# 126_06_Fmap.png
# 126_07_Fmap.png
# 126_08_Fmap.png
# 126_09_Fmap.png
# 126_10_Fmap.png
# 126_11_Fmap.png
# 126_12_Fmap.png
# 126_13_Fmap.png
# 126_14_Fmap.png
# 126_15_Fmap.png
# 127_00_Fmap.png
# 127_01_Fmap.png
# 127_02_Fmap.png
# 127_03_Fmap.png
# 127_04_Fmap.png
# 127_05_Fmap.png
# 127_06_Fmap.png
# 127_07_Fmap.png
# 127_08_Fmap.png
# 127_09_Fmap.png
# 127_10_Fmap.png
# 127_11_Fmap.png
# 127_12_Fmap.png
# 127_13_Fmap.png
# 127_14_Fmap.png
# 127_15_Fmap.png
# 128_00_Fmap.png
# 128_01_Fmap.png
# 128_02_Fmap.png
# 128_03_Fmap.png
# 128_04_Fmap.png
# 128_05_Fmap.png
# 128_06_Fmap.png
# 128_07_Fmap.png
# 128_08_Fmap.png
# 128_09_Fmap.png
# 128_10_Fmap.png
# 128_11_Fmap.png
# 128_12_Fmap.png
# 128_13_Fmap.png
# 128_14_Fmap.png
# 128_15_Fmap.png
# 129_00_Fmap.png
# 129_01_Fmap.png
# 129_02_Fmap.png
# 129_03_Fmap.png
# 129_04_Fmap.png
# 129_05_Fmap.png
# 129_06_Fmap.png
# 129_07_Fmap.png
# 129_08_Fmap.png
# 129_09_Fmap.png
# 129_10_Fmap.png
# 129_11_Fmap.png
# 129_12_Fmap.png
# 129_13_Fmap.png
# 129_14_Fmap.png
# 129_15_Fmap.png
# 130_00_Fmap.png
# 130_01_Fmap.png
# 130_02_Fmap.png
# 130_03_Fmap.png
# 130_04_Fmap.png
# 130_05_Fmap.png
# 130_06_Fmap.png
# 130_07_Fmap.png
# 130_08_Fmap.png
# 130_09_Fmap.png
# 130_10_Fmap.png
# 130_11_Fmap.png
# 130_12_Fmap.png
# 130_13_Fmap.png
# 130_14_Fmap.png
# 130_15_Fmap.png
# 131_00_Fmap.png
# 131_01_Fmap.png
# 131_02_Fmap.png
# 131_03_Fmap.png
# 131_04_Fmap.png
# 131_05_Fmap.png
# 131_06_Fmap.png
# 131_07_Fmap.png
# 131_08_Fmap.png
# 131_09_Fmap.png
# 131_10_Fmap.png
# 131_11_Fmap.png
# 131_12_Fmap.png
# 131_13_Fmap.png
# 131_14_Fmap.png
# 131_15_Fmap.png
# 132_00_Fmap.png
# 132_01_Fmap.png
# 132_02_Fmap.png
# 132_03_Fmap.png
# 132_04_Fmap.png
# 132_05_Fmap.png
# 132_06_Fmap.png
# 132_07_Fmap.png
# 132_08_Fmap.png
# 132_09_Fmap.png
# 132_10_Fmap.png
# 132_11_Fmap.png
# 132_12_Fmap.png
# 132_13_Fmap.png
# 132_14_Fmap.png
# 132_15_Fmap.png
# 133_00_Fmap.png
# 133_01_Fmap.png
# 133_02_Fmap.png
# 133_03_Fmap.png
# 133_04_Fmap.png
# 133_05_Fmap.png
# 133_06_Fmap.png
# 133_07_Fmap.png
# 133_08_Fmap.png
# 133_09_Fmap.png
# 133_10_Fmap.png
# 133_11_Fmap.png
# 133_12_Fmap.png
# 133_13_Fmap.png
# 133_14_Fmap.png
# 133_15_Fmap.png
# 134_00_Fmap.png
# 134_01_Fmap.png
# 134_02_Fmap.png
# 134_03_Fmap.png
# 134_04_Fmap.png
# 134_05_Fmap.png
# 134_06_Fmap.png
# 134_07_Fmap.png
# 134_08_Fmap.png
# 134_09_Fmap.png
# 134_10_Fmap.png
# 134_11_Fmap.png
# 134_12_Fmap.png
# 134_13_Fmap.png
# 134_14_Fmap.png
# 134_15_Fmap.png
# 135_00_Fmap.png
# 135_01_Fmap.png
# 135_02_Fmap.png
# 135_03_Fmap.png
# 135_04_Fmap.png
# 135_05_Fmap.png
# 135_06_Fmap.png
# 135_07_Fmap.png
# 135_08_Fmap.png
# 135_09_Fmap.png
# 135_10_Fmap.png
# 135_11_Fmap.png
# 135_12_Fmap.png
# 135_13_Fmap.png
# 135_14_Fmap.png
# 135_15_Fmap.png
# 136_00_Fmap.png
# 136_01_Fmap.png
# 136_02_Fmap.png
# 136_03_Fmap.png
# 136_04_Fmap.png
# 136_05_Fmap.png
# 136_06_Fmap.png
# 136_07_Fmap.png
# 136_08_Fmap.png
# 136_09_Fmap.png
# 136_10_Fmap.png
# 136_11_Fmap.png
# 136_12_Fmap.png
# 136_13_Fmap.png
# 136_14_Fmap.png
# 136_15_Fmap.png
# 137_00_Fmap.png
# 137_01_Fmap.png
# 137_02_Fmap.png
# 137_03_Fmap.png
# 137_04_Fmap.png
# 137_05_Fmap.png
# 137_06_Fmap.png
# 137_07_Fmap.png
# 137_08_Fmap.png
# 137_09_Fmap.png
# 137_10_Fmap.png
# 137_11_Fmap.png
# 137_12_Fmap.png
# 137_13_Fmap.png
# 137_14_Fmap.png
# 137_15_Fmap.png
# 138_00_Fmap.png
# 138_01_Fmap.png
# 138_02_Fmap.png
# 138_03_Fmap.png
# 138_04_Fmap.png
# 138_05_Fmap.png
# 138_06_Fmap.png
# 138_07_Fmap.png
# 138_08_Fmap.png
# 138_09_Fmap.png
# 138_10_Fmap.png
# 138_11_Fmap.png
# 138_12_Fmap.png
# 138_13_Fmap.png
# 138_14_Fmap.png
# 138_15_Fmap.png
# 139_00_Fmap.png
# 139_01_Fmap.png
# 139_02_Fmap.png
# 139_03_Fmap.png
# 139_04_Fmap.png
# 139_05_Fmap.png
# 139_06_Fmap.png
# 139_07_Fmap.png
# 139_08_Fmap.png
# 139_09_Fmap.png
# 139_10_Fmap.png
# 139_11_Fmap.png
# 139_12_Fmap.png
# 139_13_Fmap.png
# 139_14_Fmap.png
# 139_15_Fmap.png
# 140_00_Fmap.png
# 140_01_Fmap.png
# 140_02_Fmap.png
# 140_03_Fmap.png
# 140_04_Fmap.png
# 140_05_Fmap.png
# 140_06_Fmap.png
# 140_07_Fmap.png
# 140_08_Fmap.png
# 140_09_Fmap.png
# 140_10_Fmap.png
# 140_11_Fmap.png
# 140_12_Fmap.png
# 140_13_Fmap.png
# 140_14_Fmap.png
# 140_15_Fmap.png
# 141_00_Fmap.png
# 141_01_Fmap.png
# 141_02_Fmap.png
# 141_03_Fmap.png
# 141_04_Fmap.png
# 141_05_Fmap.png
# 141_06_Fmap.png
# 141_07_Fmap.png
# 141_08_Fmap.png
# 141_09_Fmap.png
# 141_10_Fmap.png
# 141_11_Fmap.png
# 141_12_Fmap.png
# 141_13_Fmap.png
# 141_14_Fmap.png
# 141_15_Fmap.png
# 142_00_Fmap.png
# 142_01_Fmap.png
# 142_02_Fmap.png
# 142_03_Fmap.png
# 142_04_Fmap.png
# 142_05_Fmap.png
# 142_06_Fmap.png
# 142_07_Fmap.png
# 142_08_Fmap.png
# 142_09_Fmap.png
# 142_10_Fmap.png
# 142_11_Fmap.png
# 142_12_Fmap.png
# 142_13_Fmap.png
# 142_14_Fmap.png
# 142_15_Fmap.png
# 143_00_Fmap.png
# 143_01_Fmap.png
# 143_02_Fmap.png
# 143_03_Fmap.png
# 143_04_Fmap.png
# 143_05_Fmap.png
# 143_06_Fmap.png
# 143_07_Fmap.png
# 143_08_Fmap.png
# 143_09_Fmap.png
# 143_10_Fmap.png
# 143_11_Fmap.png
# 143_12_Fmap.png
# 143_13_Fmap.png
# 143_14_Fmap.png
# 143_15_Fmap.png
# 144_00_Fmap.png
# 144_01_Fmap.png
# 144_02_Fmap.png
# 144_03_Fmap.png
# 144_04_Fmap.png
# 144_05_Fmap.png
# 144_06_Fmap.png
# 144_07_Fmap.png
# 144_08_Fmap.png
# 144_09_Fmap.png
# 144_10_Fmap.png
# 144_11_Fmap.png
# 144_12_Fmap.png
# 144_13_Fmap.png
# 144_14_Fmap.png
# 144_15_Fmap.png
# 145_00_Fmap.png
# 145_01_Fmap.png
# 145_02_Fmap.png
# 145_03_Fmap.png
# 145_04_Fmap.png
# 145_05_Fmap.png
# 145_06_Fmap.png
# 145_07_Fmap.png
# 145_08_Fmap.png
# 145_09_Fmap.png
# 145_10_Fmap.png
# 145_11_Fmap.png
# 145_12_Fmap.png
# 145_13_Fmap.png
# 145_14_Fmap.png
# 145_15_Fmap.png
# 146_00_Fmap.png
# 146_01_Fmap.png
# 146_02_Fmap.png
# 146_03_Fmap.png
# 146_04_Fmap.png
# 146_05_Fmap.png
# 146_06_Fmap.png
# 146_07_Fmap.png
# 146_08_Fmap.png
# 146_09_Fmap.png
# 146_10_Fmap.png
# 146_11_Fmap.png
# 146_12_Fmap.png
# 146_13_Fmap.png
# 146_14_Fmap.png
# 146_15_Fmap.png
# 147_00_Fmap.png
# 147_01_Fmap.png
# 147_02_Fmap.png
# 147_03_Fmap.png
# 147_04_Fmap.png
# 147_05_Fmap.png
# 147_06_Fmap.png
# 147_07_Fmap.png
# 147_08_Fmap.png
# 147_09_Fmap.png
# 147_10_Fmap.png
# 147_11_Fmap.png
# 147_12_Fmap.png
# 147_13_Fmap.png
# 147_14_Fmap.png
# 147_15_Fmap.png
# 148_00_Fmap.png
# 148_01_Fmap.png
# 148_02_Fmap.png
# 148_03_Fmap.png
# 148_04_Fmap.png
# 148_05_Fmap.png
# 148_06_Fmap.png
# 148_07_Fmap.png
# 148_08_Fmap.png
# 148_09_Fmap.png
# 148_10_Fmap.png
# 148_11_Fmap.png
# 148_12_Fmap.png
# 148_13_Fmap.png
# 148_14_Fmap.png
# 148_15_Fmap.png
# 149_00_Fmap.png
# 149_01_Fmap.png
# 149_02_Fmap.png
# 149_03_Fmap.png
# 149_04_Fmap.png
# 149_05_Fmap.png
# 149_06_Fmap.png
# 149_07_Fmap.png
# 149_08_Fmap.png
# 149_09_Fmap.png
# 149_10_Fmap.png
# 149_11_Fmap.png
# 149_12_Fmap.png
# 149_13_Fmap.png
# 149_14_Fmap.png
# 149_15_Fmap.png
# 150_00_Fmap.png
# 150_01_Fmap.png
# 150_02_Fmap.png
# 150_03_Fmap.png
# 150_04_Fmap.png
# 150_05_Fmap.png
# 150_06_Fmap.png
# 150_07_Fmap.png
# 150_08_Fmap.png
# 150_09_Fmap.png
# 150_10_Fmap.png
# 150_11_Fmap.png
# 150_12_Fmap.png
# 150_13_Fmap.png
# 150_14_Fmap.png
# 150_15_Fmap.png
# 151_00_Fmap.png
# 151_01_Fmap.png
# 151_02_Fmap.png
# 151_03_Fmap.png
# 151_04_Fmap.png
# 151_05_Fmap.png
# 151_06_Fmap.png
# 151_07_Fmap.png
# 151_08_Fmap.png
# 151_09_Fmap.png
# 151_10_Fmap.png
# 151_11_Fmap.png
# 151_12_Fmap.png
# 151_13_Fmap.png
# 151_14_Fmap.png
# 151_15_Fmap.png
# 152_00_Fmap.png
# 152_01_Fmap.png
# 152_02_Fmap.png
# 152_03_Fmap.png
# 152_04_Fmap.png
# 152_05_Fmap.png
# 152_06_Fmap.png
# 152_07_Fmap.png
# 152_08_Fmap.png
# 152_09_Fmap.png
# 152_10_Fmap.png
# 152_11_Fmap.png
# 152_12_Fmap.png
# 152_13_Fmap.png
# 152_14_Fmap.png
# 152_15_Fmap.png
# 153_00_Fmap.png
# 153_01_Fmap.png
# 153_02_Fmap.png
# 153_03_Fmap.png
# 153_04_Fmap.png
# 153_05_Fmap.png
# 153_06_Fmap.png
# 153_07_Fmap.png
# 153_08_Fmap.png
# 153_09_Fmap.png
# 153_10_Fmap.png
# 153_11_Fmap.png
# 153_12_Fmap.png
# 153_13_Fmap.png
# 153_14_Fmap.png
# 153_15_Fmap.png
# 154_00_Fmap.png
# 154_01_Fmap.png
# 154_02_Fmap.png
# 154_03_Fmap.png
# 154_04_Fmap.png
# 154_05_Fmap.png
# 154_06_Fmap.png
# 154_07_Fmap.png
# 154_08_Fmap.png
# 154_09_Fmap.png
# 154_10_Fmap.png
# 154_11_Fmap.png
# 154_12_Fmap.png
# 154_13_Fmap.png
# 154_14_Fmap.png
# 154_15_Fmap.png
# 155_00_Fmap.png
# 155_01_Fmap.png
# 155_02_Fmap.png
# 155_03_Fmap.png
# 155_04_Fmap.png
# 155_05_Fmap.png
# 155_06_Fmap.png
# 155_07_Fmap.png
# 155_08_Fmap.png
# 155_09_Fmap.png
# 155_10_Fmap.png
# 155_11_Fmap.png
# 155_12_Fmap.png
# 155_13_Fmap.png
# 155_14_Fmap.png
# 155_15_Fmap.png
# 156_00_Fmap.png
# 156_01_Fmap.png
# 156_02_Fmap.png
# 156_03_Fmap.png
# 156_04_Fmap.png
# 156_05_Fmap.png
# 156_06_Fmap.png
# 156_07_Fmap.png
# 156_08_Fmap.png
# 156_09_Fmap.png
# 156_10_Fmap.png
# 156_11_Fmap.png
# 156_12_Fmap.png
# 156_13_Fmap.png
# 156_14_Fmap.png
# 156_15_Fmap.png
# 157_00_Fmap.png
# 157_01_Fmap.png
# 157_02_Fmap.png
# 157_03_Fmap.png
# 157_04_Fmap.png
# 157_05_Fmap.png
# 157_06_Fmap.png
# 157_07_Fmap.png
# 157_08_Fmap.png
# 157_09_Fmap.png
# 157_10_Fmap.png
# 157_11_Fmap.png
# 157_12_Fmap.png
# 157_13_Fmap.png
# 157_14_Fmap.png
# 157_15_Fmap.png
# 158_00_Fmap.png
# 158_01_Fmap.png
# 158_02_Fmap.png
# 158_03_Fmap.png
# 158_04_Fmap.png
# 158_05_Fmap.png
# 158_06_Fmap.png
# 158_07_Fmap.png
# 158_08_Fmap.png
# 158_09_Fmap.png
# 158_10_Fmap.png
# 158_11_Fmap.png
# 158_12_Fmap.png
# 158_13_Fmap.png
# 158_14_Fmap.png
# 158_15_Fmap.png
# 159_00_Fmap.png
# 159_01_Fmap.png
# 159_02_Fmap.png
# 159_03_Fmap.png
# 159_04_Fmap.png
# 159_05_Fmap.png
# 159_06_Fmap.png
# 159_07_Fmap.png
# 159_08_Fmap.png
# 159_09_Fmap.png
# 159_10_Fmap.png
# 159_11_Fmap.png
# 159_12_Fmap.png
# 159_13_Fmap.png
# 159_14_Fmap.png
# 159_15_Fmap.png
# 160_00_Fmap.png
# 160_01_Fmap.png
# 160_02_Fmap.png
# 160_03_Fmap.png
# 160_04_Fmap.png
# 160_05_Fmap.png
# 160_06_Fmap.png
# 160_07_Fmap.png
# 160_08_Fmap.png
# 160_09_Fmap.png
# 160_10_Fmap.png
# 160_11_Fmap.png
# 160_12_Fmap.png
# 160_13_Fmap.png
# 160_14_Fmap.png
# 160_15_Fmap.png
# 161_00_Fmap.png
# 161_01_Fmap.png
# 161_02_Fmap.png
# 161_03_Fmap.png
# 161_04_Fmap.png
# 161_05_Fmap.png
# 161_06_Fmap.png
# 161_07_Fmap.png
# 161_08_Fmap.png
# 161_09_Fmap.png
# 161_10_Fmap.png
# 161_11_Fmap.png
# 161_12_Fmap.png
# 161_13_Fmap.png
# 161_14_Fmap.png
# 161_15_Fmap.png
# 162_00_Fmap.png
# 162_01_Fmap.png
# 162_02_Fmap.png
# 162_03_Fmap.png
# 162_04_Fmap.png
# 162_05_Fmap.png
# 162_06_Fmap.png
# 162_07_Fmap.png
# 162_08_Fmap.png
# 162_09_Fmap.png
# 162_10_Fmap.png
# 162_11_Fmap.png
# 162_12_Fmap.png
# 162_13_Fmap.png
# 162_14_Fmap.png
# 162_15_Fmap.png
# 163_00_Fmap.png
# 163_01_Fmap.png
# 163_02_Fmap.png
# 163_03_Fmap.png
# 163_04_Fmap.png
# 163_05_Fmap.png
# 163_06_Fmap.png
# 163_07_Fmap.png
# 163_08_Fmap.png
# 163_09_Fmap.png
# 163_10_Fmap.png
# 163_11_Fmap.png
# 163_12_Fmap.png
# 163_13_Fmap.png
# 163_14_Fmap.png
# 163_15_Fmap.png
# 164_00_Fmap.png
# 164_01_Fmap.png
# 164_02_Fmap.png
# 164_03_Fmap.png
# 164_04_Fmap.png
# 164_05_Fmap.png
# 164_06_Fmap.png
# 164_07_Fmap.png
# 164_08_Fmap.png
# 164_09_Fmap.png
# 164_10_Fmap.png
# 164_11_Fmap.png
# 164_12_Fmap.png
# 164_13_Fmap.png
# 164_14_Fmap.png
# 164_15_Fmap.png
# 165_00_Fmap.png
# 165_01_Fmap.png
# 165_02_Fmap.png
# 165_03_Fmap.png
# 165_04_Fmap.png
# 165_05_Fmap.png
# 165_06_Fmap.png
# 165_07_Fmap.png
# 165_08_Fmap.png
# 165_09_Fmap.png
# 165_10_Fmap.png
# 165_11_Fmap.png
# 165_12_Fmap.png
# 165_13_Fmap.png
# 165_14_Fmap.png
# 165_15_Fmap.png
# 166_00_Fmap.png
# 166_01_Fmap.png
# 166_02_Fmap.png
# 166_03_Fmap.png
# 166_04_Fmap.png
# 166_05_Fmap.png
# 166_06_Fmap.png
# 166_07_Fmap.png
# 166_08_Fmap.png
# 166_09_Fmap.png
# 166_10_Fmap.png
# 166_11_Fmap.png
# 166_12_Fmap.png
# 166_13_Fmap.png
# 166_14_Fmap.png
# 166_15_Fmap.png
# 167_00_Fmap.png
# 167_01_Fmap.png
# 167_02_Fmap.png
# 167_03_Fmap.png
# 167_04_Fmap.png
# 167_05_Fmap.png
# 167_06_Fmap.png
# 167_07_Fmap.png
# 167_08_Fmap.png
# 167_09_Fmap.png
# 167_10_Fmap.png
# 167_11_Fmap.png
# 167_12_Fmap.png
# 167_13_Fmap.png
# 167_14_Fmap.png
# 167_15_Fmap.png
# 168_00_Fmap.png
# 168_01_Fmap.png
# 168_02_Fmap.png
# 168_03_Fmap.png
# 168_04_Fmap.png
# 168_05_Fmap.png
# 168_06_Fmap.png
# 168_07_Fmap.png
# 168_08_Fmap.png
# 168_09_Fmap.png
# 168_10_Fmap.png
# 168_11_Fmap.png
# 168_12_Fmap.png
# 168_13_Fmap.png
# 168_14_Fmap.png
# 168_15_Fmap.png
# 169_00_Fmap.png
# 169_01_Fmap.png
# 169_02_Fmap.png
# 169_03_Fmap.png
# 169_04_Fmap.png
# 169_05_Fmap.png
# 169_06_Fmap.png
# 169_07_Fmap.png
# 169_08_Fmap.png
# 169_09_Fmap.png
# 169_10_Fmap.png
# 169_11_Fmap.png
# 169_12_Fmap.png
# 169_13_Fmap.png
# 169_14_Fmap.png
# 169_15_Fmap.png
# 170_00_Fmap.png
# 170_01_Fmap.png
# 170_02_Fmap.png
# 170_03_Fmap.png
# 170_04_Fmap.png
# 170_05_Fmap.png
# 170_06_Fmap.png
# 170_07_Fmap.png
# 170_08_Fmap.png
# 170_09_Fmap.png
# 170_10_Fmap.png
# 170_11_Fmap.png
# 170_12_Fmap.png
# 170_13_Fmap.png
# 170_14_Fmap.png
# 170_15_Fmap.png
# 171_00_Fmap.png
# 171_01_Fmap.png
# 171_02_Fmap.png
# 171_03_Fmap.png
# 171_04_Fmap.png
# 171_05_Fmap.png
# 171_06_Fmap.png
# 171_07_Fmap.png
# 171_08_Fmap.png
# 171_09_Fmap.png
# 171_10_Fmap.png
# 171_11_Fmap.png
# 171_12_Fmap.png
# 171_13_Fmap.png
# 171_14_Fmap.png
# 171_15_Fmap.png
# 172_00_Fmap.png
# 172_01_Fmap.png
# 172_02_Fmap.png
# 172_03_Fmap.png
# 172_04_Fmap.png
# 172_05_Fmap.png
# 172_06_Fmap.png
# 172_07_Fmap.png
# 172_08_Fmap.png
# 172_09_Fmap.png
# 172_10_Fmap.png
# 172_11_Fmap.png
# 172_12_Fmap.png
# 172_13_Fmap.png
# 172_14_Fmap.png
# 172_15_Fmap.png
# 173_00_Fmap.png
# 173_01_Fmap.png
# 173_02_Fmap.png
# 173_03_Fmap.png
# 173_04_Fmap.png
# 173_05_Fmap.png
# 173_06_Fmap.png
# 173_07_Fmap.png
# 173_08_Fmap.png
# 173_09_Fmap.png
# 173_10_Fmap.png
# 173_11_Fmap.png
# 173_12_Fmap.png
# 173_13_Fmap.png
# 173_14_Fmap.png
# 173_15_Fmap.png
# 174_00_Fmap.png
# 174_01_Fmap.png
# 174_02_Fmap.png
# 174_03_Fmap.png
# 174_04_Fmap.png
# 174_05_Fmap.png
# 174_06_Fmap.png
# 174_07_Fmap.png
# 174_08_Fmap.png
# 174_09_Fmap.png
# 174_10_Fmap.png
# 174_11_Fmap.png
# 174_12_Fmap.png
# 174_13_Fmap.png
# 174_14_Fmap.png
# 174_15_Fmap.png
# 175_00_Fmap.png
# 175_01_Fmap.png
# 175_02_Fmap.png
# 175_03_Fmap.png
# 175_04_Fmap.png
# 175_05_Fmap.png
# 175_06_Fmap.png
# 175_07_Fmap.png
# 175_08_Fmap.png
# 175_09_Fmap.png
# 175_10_Fmap.png
# 175_11_Fmap.png
# 175_12_Fmap.png
# 175_13_Fmap.png
# 175_14_Fmap.png
# 175_15_Fmap.png
# 176_00_Fmap.png
# 176_01_Fmap.png
# 176_02_Fmap.png
# 176_03_Fmap.png
# 176_04_Fmap.png
# 176_05_Fmap.png
# 176_06_Fmap.png
# 176_07_Fmap.png
# 176_08_Fmap.png
# 176_09_Fmap.png
# 176_10_Fmap.png
# 176_11_Fmap.png
# 176_12_Fmap.png
# 176_13_Fmap.png
# 176_14_Fmap.png
# 176_15_Fmap.png
# 177_00_Fmap.png
# 177_01_Fmap.png
# 177_02_Fmap.png
# 177_03_Fmap.png
# 177_04_Fmap.png
# 177_05_Fmap.png
# 177_06_Fmap.png
# 177_07_Fmap.png
# 177_08_Fmap.png
# 177_09_Fmap.png
# 177_10_Fmap.png
# 177_11_Fmap.png
# 177_12_Fmap.png
# 177_13_Fmap.png
# 177_14_Fmap.png
# 177_15_Fmap.png
# 178_00_Fmap.png
# 178_01_Fmap.png
# 178_02_Fmap.png
# 178_03_Fmap.png
# 178_04_Fmap.png
# 178_05_Fmap.png
# 178_06_Fmap.png
# 178_07_Fmap.png
# 178_08_Fmap.png
# 178_09_Fmap.png
# 178_10_Fmap.png
# 178_11_Fmap.png
# 178_12_Fmap.png
# 178_13_Fmap.png
# 178_14_Fmap.png
# 178_15_Fmap.png
# 179_00_Fmap.png
# 179_01_Fmap.png
# 179_02_Fmap.png
# 179_03_Fmap.png
# 179_04_Fmap.png
# 179_05_Fmap.png
# 179_06_Fmap.png
# 179_07_Fmap.png
# 179_08_Fmap.png
# 179_09_Fmap.png
# 179_10_Fmap.png
# 179_11_Fmap.png
# 179_12_Fmap.png
# 179_13_Fmap.png
# 179_14_Fmap.png
# 179_15_Fmap.png
# 180_00_Fmap.png
# 180_01_Fmap.png
# 180_02_Fmap.png
# 180_03_Fmap.png
# 180_04_Fmap.png
# 180_05_Fmap.png
# 180_06_Fmap.png
# 180_07_Fmap.png
# 180_08_Fmap.png
# 180_09_Fmap.png
# 180_10_Fmap.png
# 180_11_Fmap.png
# 180_12_Fmap.png
# 180_13_Fmap.png
# 180_14_Fmap.png
# 180_15_Fmap.png
# 181_00_Fmap.png
# 181_01_Fmap.png
# 181_02_Fmap.png
# 181_03_Fmap.png
# 181_04_Fmap.png
# 181_05_Fmap.png
# 181_06_Fmap.png
# 181_07_Fmap.png
# 181_08_Fmap.png
# 181_09_Fmap.png
# 181_10_Fmap.png
# 181_11_Fmap.png
# 181_12_Fmap.png
# 181_13_Fmap.png
# 181_14_Fmap.png
# 181_15_Fmap.png
# 182_00_Fmap.png
# 182_01_Fmap.png
# 182_02_Fmap.png
# 182_03_Fmap.png
# 182_04_Fmap.png
# 182_05_Fmap.png
# 182_06_Fmap.png
# 182_07_Fmap.png
# 182_08_Fmap.png
# 182_09_Fmap.png
# 182_10_Fmap.png
# 182_11_Fmap.png
# 182_12_Fmap.png
# 182_13_Fmap.png
# 182_14_Fmap.png
# 182_15_Fmap.png
# 183_00_Fmap.png
# 183_01_Fmap.png
# 183_02_Fmap.png
# 183_03_Fmap.png
# 183_04_Fmap.png
# 183_05_Fmap.png
# 183_06_Fmap.png
# 183_07_Fmap.png
# 183_08_Fmap.png
# 183_09_Fmap.png
# 183_10_Fmap.png
# 183_11_Fmap.png
# 183_12_Fmap.png
# 183_13_Fmap.png
# 183_14_Fmap.png
# 183_15_Fmap.png
# 184_00_Fmap.png
# 184_01_Fmap.png
# 184_02_Fmap.png
# 184_03_Fmap.png
# 184_04_Fmap.png
# 184_05_Fmap.png
# 184_06_Fmap.png
# 184_07_Fmap.png
# 184_08_Fmap.png
# 184_09_Fmap.png
# 184_10_Fmap.png
# 184_11_Fmap.png
# 184_12_Fmap.png
# 184_13_Fmap.png
# 184_14_Fmap.png
# 184_15_Fmap.png
# 185_00_Fmap.png
# 185_01_Fmap.png
# 185_02_Fmap.png
# 185_03_Fmap.png
# 185_04_Fmap.png
# 185_05_Fmap.png
# 185_06_Fmap.png
# 185_07_Fmap.png
# 185_08_Fmap.png
# 185_09_Fmap.png
# 185_10_Fmap.png
# 185_11_Fmap.png
# 185_12_Fmap.png
# 185_13_Fmap.png
# 185_14_Fmap.png
# 185_15_Fmap.png
# 186_00_Fmap.png
# 186_01_Fmap.png
# 186_02_Fmap.png
# 186_03_Fmap.png
# 186_04_Fmap.png
# 186_05_Fmap.png
# 186_06_Fmap.png
# 186_07_Fmap.png
# 186_08_Fmap.png
# 186_09_Fmap.png
# 186_10_Fmap.png
# 186_11_Fmap.png
# 186_12_Fmap.png
# 186_13_Fmap.png
# 186_14_Fmap.png
# 186_15_Fmap.png
# 187_00_Fmap.png
# 187_01_Fmap.png
# 187_02_Fmap.png
# 187_03_Fmap.png
# 187_04_Fmap.png
# 187_05_Fmap.png
# 187_06_Fmap.png
# 187_07_Fmap.png
# 187_08_Fmap.png
# 187_09_Fmap.png
# 187_10_Fmap.png
# 187_11_Fmap.png
# 187_12_Fmap.png
# 187_13_Fmap.png
# 187_14_Fmap.png
# 187_15_Fmap.png
# 188_00_Fmap.png
# 188_01_Fmap.png
# 188_02_Fmap.png
# 188_03_Fmap.png
# 188_04_Fmap.png
# 188_05_Fmap.png
# 188_06_Fmap.png
# 188_07_Fmap.png
# ...
# 238_08_Fmap.png
# 238_09_Fmap.png
# 238_10_Fmap.png
# 238_11_Fmap.png
# 238_12_Fmap.png
# 238_13_Fmap.png
# 238_14_Fmap.png
# 238_15_Fmap.png
# 239_00_Fmap.png
# 239_01_Fmap.png
# 239_02_Fmap.png
# 239_03_Fmap.png
# 239_04_Fmap.png
# 239_05_Fmap.png
# 239_06_Fmap.png
# 239_07_Fmap.png
# 239_08_Fmap.png
# 239_09_Fmap.png
# 239_10_Fmap.png
# 239_11_Fmap.png
# 239_12_Fmap.png
# 239_13_Fmap.png
# 239_14_Fmap.png
# 239_15_Fmap.png
# 240_00_Fmap.png
# 240_01_Fmap.png
# 240_02_Fmap.png
# 240_03_Fmap.png
# 240_04_Fmap.png
# 240_05_Fmap.png
# 240_06_Fmap.png
# 240_07_Fmap.png
# 240_08_Fmap.png
# 240_09_Fmap.png
# 240_10_Fmap.png
# 240_11_Fmap.png
# 240_12_Fmap.png
# 240_13_Fmap.png
# 240_14_Fmap.png
# 240_15_Fmap.png
# 241_00_Fmap.png
# 241_01_Fmap.png
# 241_02_Fmap.png
# 241_03_Fmap.png
# 241_04_Fmap.png
# 241_05_Fmap.png
# 241_06_Fmap.png
# 241_07_Fmap.png
# 241_08_Fmap.png
# 241_09_Fmap.png
# 241_10_Fmap.png
# 241_11_Fmap.png
# 241_12_Fmap.png
# 241_13_Fmap.png
# 241_14_Fmap.png
# 241_15_Fmap.png
# 242_00_Fmap.png
# 242_01_Fmap.png
# 242_02_Fmap.png
# 242_03_Fmap.png
# 242_04_Fmap.png
# 242_05_Fmap.png
# 242_06_Fmap.png
# 242_07_Fmap.png
# 242_08_Fmap.png
# 242_09_Fmap.png
# 242_10_Fmap.png
# 242_11_Fmap.png
# 242_12_Fmap.png
# 242_13_Fmap.png
# 242_14_Fmap.png
# 242_15_Fmap.png
# 243_00_Fmap.png
# 243_01_Fmap.png
# 243_02_Fmap.png
# 243_03_Fmap.png
# 243_04_Fmap.png
# 243_05_Fmap.png
# 243_06_Fmap.png
# 243_07_Fmap.png
# 243_08_Fmap.png
# 243_09_Fmap.png
# 243_10_Fmap.png
# 243_11_Fmap.png
# 243_12_Fmap.png
# 243_13_Fmap.png
# 243_14_Fmap.png
# 243_15_Fmap.png
# 244_00_Fmap.png
# 244_01_Fmap.png
# 244_02_Fmap.png
# 244_03_Fmap.png
# 244_04_Fmap.png
# 244_05_Fmap.png
# 244_06_Fmap.png
# 244_07_Fmap.png
# 244_08_Fmap.png
# 244_09_Fmap.png
# 244_10_Fmap.png
# 244_11_Fmap.png
# 244_12_Fmap.png
# 244_13_Fmap.png
# 244_14_Fmap.png
# 244_15_Fmap.png
# 245_00_Fmap.png
# 245_01_Fmap.png
# 245_02_Fmap.png
# 245_03_Fmap.png
# 245_04_Fmap.png
# 245_05_Fmap.png
# 245_06_Fmap.png
# 245_07_Fmap.png
# 245_08_Fmap.png
# 245_09_Fmap.png
# 245_10_Fmap.png
# 245_11_Fmap.png
# 245_12_Fmap.png
# 245_13_Fmap.png
# 245_14_Fmap.png
# 245_15_Fmap.png
# 246_00_Fmap.png
# 246_01_Fmap.png
# 246_02_Fmap.png
# 246_03_Fmap.png
# 246_04_Fmap.png
# 246_05_Fmap.png
# 246_06_Fmap.png
# 246_07_Fmap.png
# 246_08_Fmap.png
# 246_09_Fmap.png
# 246_10_Fmap.png
# 246_11_Fmap.png
# 246_12_Fmap.png
# 246_13_Fmap.png
# 246_14_Fmap.png
# 246_15_Fmap.png
# 247_00_Fmap.png
# 247_01_Fmap.png
# 247_02_Fmap.png
# 247_03_Fmap.png
# 247_04_Fmap.png
# 247_05_Fmap.png
# 247_06_Fmap.png
# 247_07_Fmap.png
# 247_08_Fmap.png
# 247_09_Fmap.png
# 247_10_Fmap.png
# 247_11_Fmap.png
# 247_12_Fmap.png
# 247_13_Fmap.png
# 247_14_Fmap.png
# 247_15_Fmap.png
# 248_00_Fmap.png
# 248_01_Fmap.png
# 248_02_Fmap.png
# 248_03_Fmap.png
# 248_04_Fmap.png
# 248_05_Fmap.png
# 248_06_Fmap.png
# 248_07_Fmap.png
# 248_08_Fmap.png
# 248_09_Fmap.png
# 248_10_Fmap.png
# 248_11_Fmap.png
# 248_12_Fmap.png
# 248_13_Fmap.png
# 248_14_Fmap.png
# 248_15_Fmap.png
# 249_00_Fmap.png
# 249_01_Fmap.png
# 249_02_Fmap.png
# 249_03_Fmap.png
# 249_04_Fmap.png
# 249_05_Fmap.png
# 249_06_Fmap.png
# 249_07_Fmap.png
# 249_08_Fmap.png
# 249_09_Fmap.png
# 249_10_Fmap.png
# 249_11_Fmap.png
# 249_12_Fmap.png
# 249_13_Fmap.png
# 249_14_Fmap.png
# 249_15_Fmap.png
# 250_00_Fmap.png
# 250_01_Fmap.png
# 250_02_Fmap.png
# 250_03_Fmap.png
# 250_04_Fmap.png
# 250_05_Fmap.png
# 250_06_Fmap.png
# 250_07_Fmap.png
# 250_08_Fmap.png
# 250_09_Fmap.png
# 250_10_Fmap.png
# 250_11_Fmap.png
# 250_12_Fmap.png
# 250_13_Fmap.png
# 250_14_Fmap.png
# 250_15_Fmap.png
# 251_00_Fmap.png
# 251_01_Fmap.png
# 251_02_Fmap.png
# 251_03_Fmap.png
# 251_04_Fmap.png
# 251_05_Fmap.png
# 251_06_Fmap.png
# 251_07_Fmap.png
# 251_08_Fmap.png
# 251_09_Fmap.png
# 251_10_Fmap.png
# 251_11_Fmap.png
# 251_12_Fmap.png
# 251_13_Fmap.png
# 251_14_Fmap.png
# 251_15_Fmap.png
# 252_00_Fmap.png
# 252_01_Fmap.png
# 252_02_Fmap.png
# 252_03_Fmap.png
# 252_04_Fmap.png
# 252_05_Fmap.png
# 252_06_Fmap.png
# 252_07_Fmap.png
# 252_08_Fmap.png
# 252_09_Fmap.png
# 252_10_Fmap.png
# 252_11_Fmap.png
# 252_12_Fmap.png
# 252_13_Fmap.png
# 252_14_Fmap.png
# 252_15_Fmap.png
# 253_00_Fmap.png
# 253_01_Fmap.png
# 253_02_Fmap.png
# 253_03_Fmap.png
# 253_04_Fmap.png
# 253_05_Fmap.png
# 253_06_Fmap.png
# 253_07_Fmap.png
# 253_08_Fmap.png
# 253_09_Fmap.png
# 253_10_Fmap.png
# 253_11_Fmap.png
# 253_12_Fmap.png
# 253_13_Fmap.png
# 253_14_Fmap.png
# 253_15_Fmap.png
# 254_00_Fmap.png
# 254_01_Fmap.png
# 254_02_Fmap.png
# 254_03_Fmap.png
# 254_04_Fmap.png
# 254_05_Fmap.png
# 254_06_Fmap.png
# 254_07_Fmap.png
# 254_08_Fmap.png
# 254_09_Fmap.png
# 254_10_Fmap.png
# 254_11_Fmap.png
# 254_12_Fmap.png
# 254_13_Fmap.png
# 254_14_Fmap.png
# 254_15_Fmap.png
# 255_00_Fmap.png
# 255_01_Fmap.png
# 255_02_Fmap.png
# 255_03_Fmap.png
# 255_04_Fmap.png
# 255_05_Fmap.png
# 255_06_Fmap.png
# 255_07_Fmap.png
# 255_08_Fmap.png
# 255_09_Fmap.png
# 255_10_Fmap.png
# 255_11_Fmap.png
# 255_12_Fmap.png
# 255_13_Fmap.png
# 255_14_Fmap.png
# 255_15_Fmap.png
# 256_00_Fmap.png
# 256_01_Fmap.png
# 256_02_Fmap.png
# 256_03_Fmap.png
# 256_04_Fmap.png
# 256_05_Fmap.png
# 256_06_Fmap.png
# 256_07_Fmap.png
# 256_08_Fmap.png
# 256_09_Fmap.png
# 256_10_Fmap.png
# 256_11_Fmap.png
# 256_12_Fmap.png
# 256_13_Fmap.png
# 256_14_Fmap.png
# 256_15_Fmap.png
# 257_00_Fmap.png
# 257_01_Fmap.png
# 257_02_Fmap.png
# 257_03_Fmap.png
# 257_04_Fmap.png
# 257_05_Fmap.png
# 257_06_Fmap.png
# 257_07_Fmap.png
# 257_08_Fmap.png
# 257_09_Fmap.png
# 257_10_Fmap.png
# 257_11_Fmap.png
# 257_12_Fmap.png
# 257_13_Fmap.png
# 257_14_Fmap.png
# 257_15_Fmap.png
# 258_00_Fmap.png
# 258_01_Fmap.png
# 258_02_Fmap.png
# 258_03_Fmap.png
# 258_04_Fmap.png
# 258_05_Fmap.png
# 258_06_Fmap.png
# 258_07_Fmap.png
# 258_08_Fmap.png
# 258_09_Fmap.png
# 258_10_Fmap.png
# 258_11_Fmap.png
# 258_12_Fmap.png
# 258_13_Fmap.png
# 258_14_Fmap.png
# 258_15_Fmap.png
# 259_00_Fmap.png
# 259_01_Fmap.png
# 259_02_Fmap.png
# 259_03_Fmap.png
# 259_04_Fmap.png
# 259_05_Fmap.png
# 259_06_Fmap.png
# 259_07_Fmap.png
# 259_08_Fmap.png
# 259_09_Fmap.png
# 259_10_Fmap.png
# 259_11_Fmap.png
# 259_12_Fmap.png
# 259_13_Fmap.png
# 259_14_Fmap.png
# 259_15_Fmap.png
# 260_00_Fmap.png
# 260_01_Fmap.png
# 260_02_Fmap.png
# 260_03_Fmap.png
# 260_04_Fmap.png
# 260_05_Fmap.png
# 260_06_Fmap.png
# 260_07_Fmap.png
# 260_08_Fmap.png
# 260_09_Fmap.png
# 260_10_Fmap.png
# 260_11_Fmap.png
# 260_12_Fmap.png
# 260_13_Fmap.png
# 260_14_Fmap.png
# 260_15_Fmap.png
# 261_00_Fmap.png
# 261_01_Fmap.png
# 261_02_Fmap.png
# 261_03_Fmap.png
# 261_04_Fmap.png
# 261_05_Fmap.png
# 261_06_Fmap.png
# 261_07_Fmap.png
# 261_08_Fmap.png
# 261_09_Fmap.png
# 261_10_Fmap.png
# 261_11_Fmap.png
# 261_12_Fmap.png
# 261_13_Fmap.png
# 261_14_Fmap.png
# 261_15_Fmap.png
# 262_00_Fmap.png
# 262_01_Fmap.png
# 262_02_Fmap.png
# 262_03_Fmap.png
# 262_04_Fmap.png
# 262_05_Fmap.png
# 262_06_Fmap.png
# 262_07_Fmap.png
# 262_08_Fmap.png
# 262_09_Fmap.png
# 262_10_Fmap.png
# 262_11_Fmap.png
# 262_12_Fmap.png
# 262_13_Fmap.png
# 262_14_Fmap.png
# 262_15_Fmap.png
# 263_00_Fmap.png
# 263_01_Fmap.png
# 263_02_Fmap.png
# 263_03_Fmap.png
# 263_04_Fmap.png
# 263_05_Fmap.png
# 263_06_Fmap.png
# 263_07_Fmap.png
# 263_08_Fmap.png
# 263_09_Fmap.png
# 263_10_Fmap.png
# 263_11_Fmap.png
# 263_12_Fmap.png
# 263_13_Fmap.png
# 263_14_Fmap.png
# 263_15_Fmap.png
# 264_00_Fmap.png
# 264_01_Fmap.png
# 264_02_Fmap.png
# 264_03_Fmap.png
# 264_04_Fmap.png
# 264_05_Fmap.png
# 264_06_Fmap.png
# 264_07_Fmap.png
# 264_08_Fmap.png
# 264_09_Fmap.png
# 264_10_Fmap.png
# 264_11_Fmap.png
# 264_12_Fmap.png
# 264_13_Fmap.png
# 264_14_Fmap.png
# 264_15_Fmap.png
# 265_00_Fmap.png
# 265_01_Fmap.png
# 265_02_Fmap.png
# 265_03_Fmap.png
# 265_04_Fmap.png
# 265_05_Fmap.png
# 265_06_Fmap.png
# 265_07_Fmap.png
# 265_08_Fmap.png
# 265_09_Fmap.png
# 265_10_Fmap.png
# 265_11_Fmap.png
# 265_12_Fmap.png
# 265_13_Fmap.png
# 265_14_Fmap.png
# 265_15_Fmap.png
# 266_00_Fmap.png
# 266_01_Fmap.png
# 266_02_Fmap.png
# 266_03_Fmap.png
# 266_04_Fmap.png
# 266_05_Fmap.png
# 266_06_Fmap.png
# 266_07_Fmap.png
# 266_08_Fmap.png
# 266_09_Fmap.png
# 266_10_Fmap.png
# 266_11_Fmap.png
# 266_12_Fmap.png
# 266_13_Fmap.png
# 266_14_Fmap.png
# 266_15_Fmap.png
# 267_00_Fmap.png
# 267_01_Fmap.png
# 267_02_Fmap.png
# 267_03_Fmap.png
# 267_04_Fmap.png
# 267_05_Fmap.png
# 267_06_Fmap.png
# 267_07_Fmap.png
# 267_08_Fmap.png
# 267_09_Fmap.png
# 267_10_Fmap.png
# 267_11_Fmap.png
# 267_12_Fmap.png
# 267_13_Fmap.png
# 267_14_Fmap.png
# 267_15_Fmap.png
# 268_00_Fmap.png
# 268_01_Fmap.png
# 268_02_Fmap.png
# 268_03_Fmap.png
# 268_04_Fmap.png
# 268_05_Fmap.png
# 268_06_Fmap.png
# 268_07_Fmap.png
# 268_08_Fmap.png
# 268_09_Fmap.png
# 268_10_Fmap.png
# 268_11_Fmap.png
# 268_12_Fmap.png
# 268_13_Fmap.png
# 268_14_Fmap.png
# 268_15_Fmap.png
# 269_00_Fmap.png
# 269_01_Fmap.png
# 269_02_Fmap.png
# 269_03_Fmap.png
# 269_04_Fmap.png
# 269_05_Fmap.png
# 269_06_Fmap.png
# 269_07_Fmap.png
# 269_08_Fmap.png
# 269_09_Fmap.png
# 269_10_Fmap.png
# 269_11_Fmap.png
# 269_12_Fmap.png
# 269_13_Fmap.png
# 269_14_Fmap.png
# 269_15_Fmap.png
# 270_00_Fmap.png
# 270_01_Fmap.png
# 270_02_Fmap.png
# 270_03_Fmap.png
# 270_04_Fmap.png
# 270_05_Fmap.png
# 270_06_Fmap.png
# 270_07_Fmap.png
# 270_08_Fmap.png
# 270_09_Fmap.png
# 270_10_Fmap.png
# 270_11_Fmap.png
# 270_12_Fmap.png
# 270_13_Fmap.png
# 270_14_Fmap.png
# 270_15_Fmap.png
# 271_00_Fmap.png
# 271_01_Fmap.png
# 271_02_Fmap.png
# 271_03_Fmap.png
# 271_04_Fmap.png
# 271_05_Fmap.png
# 271_06_Fmap.png
# 271_07_Fmap.png
# 271_08_Fmap.png
# 271_09_Fmap.png
# 271_10_Fmap.png
# 271_11_Fmap.png
# 271_12_Fmap.png
# 271_13_Fmap.png
# 271_14_Fmap.png
# 271_15_Fmap.png
# 272_00_Fmap.png
# 272_01_Fmap.png
# 272_02_Fmap.png
# 272_03_Fmap.png
# 272_04_Fmap.png
# 272_05_Fmap.png
# 272_06_Fmap.png
# 272_07_Fmap.png
# 272_08_Fmap.png
# 272_09_Fmap.png
# 272_10_Fmap.png
# 272_11_Fmap.png
# 272_12_Fmap.png
# 272_13_Fmap.png
# 272_14_Fmap.png
# 272_15_Fmap.png
# 273_00_Fmap.png
# 273_01_Fmap.png
# 273_02_Fmap.png
# 273_03_Fmap.png
# 273_04_Fmap.png
# 273_05_Fmap.png
# 273_06_Fmap.png
# 273_07_Fmap.png
# 273_08_Fmap.png
# 273_09_Fmap.png
# 273_10_Fmap.png
# 273_11_Fmap.png
# 273_12_Fmap.png
# 273_13_Fmap.png
# 273_14_Fmap.png
# 273_15_Fmap.png
# 274_00_Fmap.png
# 274_01_Fmap.png
# 274_02_Fmap.png
# 274_03_Fmap.png
# 274_04_Fmap.png
# 274_05_Fmap.png
# 274_06_Fmap.png
# 274_07_Fmap.png
# 274_08_Fmap.png
# 274_09_Fmap.png
# 274_10_Fmap.png
# 274_11_Fmap.png
# 274_12_Fmap.png
# 274_13_Fmap.png
# 274_14_Fmap.png
# 274_15_Fmap.png
# 275_00_Fmap.png
# 275_01_Fmap.png
# 275_02_Fmap.png
# 275_03_Fmap.png
# 275_04_Fmap.png
# 275_05_Fmap.png
# 275_06_Fmap.png
# 275_07_Fmap.png
# 275_08_Fmap.png
# 275_09_Fmap.png
# 275_10_Fmap.png
# 275_11_Fmap.png
# 275_12_Fmap.png
# 275_13_Fmap.png
# 275_14_Fmap.png
# 275_15_Fmap.png
# 276_00_Fmap.png
# 276_01_Fmap.png
# 276_02_Fmap.png
# 276_03_Fmap.png
# 276_04_Fmap.png
# 276_05_Fmap.png
# 276_06_Fmap.png
# 276_07_Fmap.png
# 276_08_Fmap.png
# 276_09_Fmap.png
# 276_10_Fmap.png
# 276_11_Fmap.png
# 276_12_Fmap.png
# 276_13_Fmap.png
# 276_14_Fmap.png
# 276_15_Fmap.png
# 277_00_Fmap.png
# 277_01_Fmap.png
# 277_02_Fmap.png
# 277_03_Fmap.png
# 277_04_Fmap.png
# 277_05_Fmap.png
# 277_06_Fmap.png
# 277_07_Fmap.png
# 277_08_Fmap.png
# 277_09_Fmap.png
# 277_10_Fmap.png
# 277_11_Fmap.png
# 277_12_Fmap.png
# 277_13_Fmap.png
# 277_14_Fmap.png
# 277_15_Fmap.png
# 278_00_Fmap.png
# 278_01_Fmap.png
# 278_02_Fmap.png
# 278_03_Fmap.png
# 278_04_Fmap.png
# 278_05_Fmap.png
# 278_06_Fmap.png
# 278_07_Fmap.png
# 278_08_Fmap.png
# 278_09_Fmap.png
# 278_10_Fmap.png
# 278_11_Fmap.png
# 278_12_Fmap.png
# 278_13_Fmap.png
# 278_14_Fmap.png
# 278_15_Fmap.png
# 279_00_Fmap.png
# 279_01_Fmap.png
# 279_02_Fmap.png
# 279_03_Fmap.png
# 279_04_Fmap.png
# 279_05_Fmap.png
# 279_06_Fmap.png
# 279_07_Fmap.png
# 279_08_Fmap.png
# 279_09_Fmap.png
# 279_10_Fmap.png
# 279_11_Fmap.png
# 279_12_Fmap.png
# 279_13_Fmap.png
# 279_14_Fmap.png
# 279_15_Fmap.png
# 280_00_Fmap.png
# 280_01_Fmap.png
# 280_02_Fmap.png
# 280_03_Fmap.png
# 280_04_Fmap.png
# 280_05_Fmap.png
# 280_06_Fmap.png
# 280_07_Fmap.png
# 280_08_Fmap.png
# 280_09_Fmap.png
# 280_10_Fmap.png
# 280_11_Fmap.png
# 280_12_Fmap.png
# 280_13_Fmap.png
# 280_14_Fmap.png
# 280_15_Fmap.png
# 281_00_Fmap.png
# 281_01_Fmap.png
# 281_02_Fmap.png
# 281_03_Fmap.png
# 281_04_Fmap.png
# 281_05_Fmap.png
# 281_06_Fmap.png
# 281_07_Fmap.png
# 281_08_Fmap.png
# 281_09_Fmap.png
# 281_10_Fmap.png
# 281_11_Fmap.png
# 281_12_Fmap.png
# 281_13_Fmap.png
# 281_14_Fmap.png
# 281_15_Fmap.png
# 282_00_Fmap.png
# 282_01_Fmap.png
# 282_02_Fmap.png
# 282_03_Fmap.png
# 282_04_Fmap.png
# 282_05_Fmap.png
# 282_06_Fmap.png
# 282_07_Fmap.png
# 282_08_Fmap.png
# 282_09_Fmap.png
# 282_10_Fmap.png
# 282_11_Fmap.png
# 282_12_Fmap.png
# 282_13_Fmap.png
# 282_14_Fmap.png
# 282_15_Fmap.png
# 283_00_Fmap.png
# 283_01_Fmap.png
# 283_02_Fmap.png
# 283_03_Fmap.png
# 283_04_Fmap.png
# 283_05_Fmap.png
# 283_06_Fmap.png
# 283_07_Fmap.png
# 283_08_Fmap.png
# 283_09_Fmap.png
# 283_10_Fmap.png
# 283_11_Fmap.png
# 283_12_Fmap.png
# 283_13_Fmap.png
# 283_14_Fmap.png
# 283_15_Fmap.png
# 284_00_Fmap.png
# 284_01_Fmap.png
# 284_02_Fmap.png
# 284_03_Fmap.png
# 284_04_Fmap.png
# 284_05_Fmap.png
# 284_06_Fmap.png
# 284_07_Fmap.png
# 284_08_Fmap.png
# 284_09_Fmap.png
# 284_10_Fmap.png
# 284_11_Fmap.png
# 284_12_Fmap.png
# 284_13_Fmap.png
# 284_14_Fmap.png
# 284_15_Fmap.png
# 285_00_Fmap.png
# 285_01_Fmap.png
# 285_02_Fmap.png
# 285_03_Fmap.png
# 285_04_Fmap.png
# 285_05_Fmap.png
# 285_06_Fmap.png
# 285_07_Fmap.png
# 285_08_Fmap.png
# 285_09_Fmap.png
# 285_10_Fmap.png
# 285_11_Fmap.png
# 285_12_Fmap.png
# 285_13_Fmap.png
# 285_14_Fmap.png
# 285_15_Fmap.png
# 286_00_Fmap.png
# 286_01_Fmap.png
# 286_02_Fmap.png
# 286_03_Fmap.png
# 286_04_Fmap.png
# 286_05_Fmap.png
# 286_06_Fmap.png
# 286_07_Fmap.png
# 286_08_Fmap.png
# 286_09_Fmap.png
# 286_10_Fmap.png
# 286_11_Fmap.png
# 286_12_Fmap.png
# 286_13_Fmap.png
# 286_14_Fmap.png
# 286_15_Fmap.png
# 287_00_Fmap.png
# 287_01_Fmap.png
# 287_02_Fmap.png
# 287_03_Fmap.png
# 287_04_Fmap.png
# 287_05_Fmap.png
# 287_06_Fmap.png
# 287_07_Fmap.png
# 287_08_Fmap.png
# 287_09_Fmap.png
# 287_10_Fmap.png
# 287_11_Fmap.png
# 287_12_Fmap.png
# 287_13_Fmap.png
# 287_14_Fmap.png
# 287_15_Fmap.png
# 288_00_Fmap.png
# 288_01_Fmap.png
# 288_02_Fmap.png
# 288_03_Fmap.png
# 288_04_Fmap.png
# 288_05_Fmap.png
# 288_06_Fmap.png
# 288_07_Fmap.png
# 288_08_Fmap.png
# 288_09_Fmap.png
# 288_10_Fmap.png
# 288_11_Fmap.png
# 288_12_Fmap.png
# 288_13_Fmap.png
# 288_14_Fmap.png
# 288_15_Fmap.png
# 289_00_Fmap.png
# 289_01_Fmap.png
# 289_02_Fmap.png
# 289_03_Fmap.png
# 289_04_Fmap.png
# 289_05_Fmap.png
# 289_06_Fmap.png
# 289_07_Fmap.png
# 289_08_Fmap.png
# 289_09_Fmap.png
# 289_10_Fmap.png
# 289_11_Fmap.png
# 289_12_Fmap.png
# 289_13_Fmap.png
# 289_14_Fmap.png
# 289_15_Fmap.png
# 290_00_Fmap.png
# 290_01_Fmap.png
# 290_02_Fmap.png
# 290_03_Fmap.png
# 290_04_Fmap.png
# 290_05_Fmap.png
# 290_06_Fmap.png
# 290_07_Fmap.png
# 290_08_Fmap.png
# 290_09_Fmap.png
# 290_10_Fmap.png
# 290_11_Fmap.png
# 290_12_Fmap.png
# 290_13_Fmap.png
# 290_14_Fmap.png
# 290_15_Fmap.png
# 291_00_Fmap.png
# 291_01_Fmap.png
# 291_02_Fmap.png
# 291_03_Fmap.png
# 291_04_Fmap.png
# 291_05_Fmap.png
# 291_06_Fmap.png
# 291_07_Fmap.png
# 291_08_Fmap.png
# 291_09_Fmap.png
# 291_10_Fmap.png
# 291_11_Fmap.png
# 291_12_Fmap.png
# 291_13_Fmap.png
# 291_14_Fmap.png
# 291_15_Fmap.png
# 292_00_Fmap.png
# 292_01_Fmap.png
# 292_02_Fmap.png
# 292_03_Fmap.png
# 292_04_Fmap.png
# 292_05_Fmap.png
# 292_06_Fmap.png
# 292_07_Fmap.png
# 292_08_Fmap.png
# 292_09_Fmap.png
# 292_10_Fmap.png
# 292_11_Fmap.png
# 292_12_Fmap.png
# 292_13_Fmap.png
# 292_14_Fmap.png
# 292_15_Fmap.png
# 293_00_Fmap.png
# 293_01_Fmap.png
# 293_02_Fmap.png
# 293_03_Fmap.png
# 293_04_Fmap.png
# 293_05_Fmap.png
# 293_06_Fmap.png
# 293_07_Fmap.png
# 293_08_Fmap.png
# 293_09_Fmap.png
# 293_10_Fmap.png
# 293_11_Fmap.png
# 293_12_Fmap.png
# 293_13_Fmap.png
# 293_14_Fmap.png
# 293_15_Fmap.png
# 294_00_Fmap.png
# 294_01_Fmap.png
# 294_02_Fmap.png
# 294_03_Fmap.png
# 294_04_Fmap.png
# 294_05_Fmap.png
# 294_06_Fmap.png
# 294_07_Fmap.png
# 294_08_Fmap.png
# 294_09_Fmap.png
# 294_10_Fmap.png
# 294_11_Fmap.png
# 294_12_Fmap.png
# 294_13_Fmap.png
# 294_14_Fmap.png
# 294_15_Fmap.png
# 295_00_Fmap.png
# 295_01_Fmap.png
# 295_02_Fmap.png
# 295_03_Fmap.png
# 295_04_Fmap.png
# 295_05_Fmap.png
# 295_06_Fmap.png
# 295_07_Fmap.png
# 295_08_Fmap.png
# 295_09_Fmap.png
# 295_10_Fmap.png
# 295_11_Fmap.png
# 295_12_Fmap.png
# 295_13_Fmap.png
# 295_14_Fmap.png
# 295_15_Fmap.png
# 296_00_Fmap.png
# 296_01_Fmap.png
# 296_02_Fmap.png
# 296_03_Fmap.png
# 296_04_Fmap.png
# 296_05_Fmap.png
# 296_06_Fmap.png
# 296_07_Fmap.png
# 296_08_Fmap.png
# 296_09_Fmap.png
# 296_10_Fmap.png
# 296_11_Fmap.png
# 296_12_Fmap.png
# 296_13_Fmap.png
# 296_14_Fmap.png
# 296_15_Fmap.png
# 297_00_Fmap.png
# 297_01_Fmap.png
# 297_02_Fmap.png
# 297_03_Fmap.png
# 297_04_Fmap.png
# 297_05_Fmap.png
# 297_06_Fmap.png
# 297_07_Fmap.png
# 297_08_Fmap.png
# 297_09_Fmap.png
# 297_10_Fmap.png
# 297_11_Fmap.png
# 297_12_Fmap.png
# 297_13_Fmap.png
# 297_14_Fmap.png
# 297_15_Fmap.png
# 298_00_Fmap.png
# 298_01_Fmap.png
# 298_02_Fmap.png
# 298_03_Fmap.png
# 298_04_Fmap.png
# 298_05_Fmap.png
# 298_06_Fmap.png
# 298_07_Fmap.png
# 298_08_Fmap.png
# 298_09_Fmap.png
# 298_10_Fmap.png
# 298_11_Fmap.png
# 298_12_Fmap.png
# 298_13_Fmap.png
# 298_14_Fmap.png
# 298_15_Fmap.png
# 299_00_Fmap.png
# 299_01_Fmap.png
# 299_02_Fmap.png
# 299_03_Fmap.png
# 299_04_Fmap.png
# 299_05_Fmap.png
# 299_06_Fmap.png
# 299_07_Fmap.png
# 299_08_Fmap.png
# 299_09_Fmap.png
# 299_10_Fmap.png
# 299_11_Fmap.png
# 299_12_Fmap.png
# 299_13_Fmap.png
# 299_14_Fmap.png
# 299_15_Fmap.png
# 300_00_Fmap.png
# 300_01_Fmap.png
# 300_02_Fmap.png
# 300_03_Fmap.png
# 300_04_Fmap.png
# 300_05_Fmap.png
# 300_06_Fmap.png
# 300_07_Fmap.png
# 300_08_Fmap.png
# 300_09_Fmap.png
# 300_10_Fmap.png
# 300_11_Fmap.png
# 300_12_Fmap.png
# 300_13_Fmap.png
# 300_14_Fmap.png
# 300_15_Fmap.png

# %%
two_vecs = tmp_reshaped[-2]
x, y = zip(*two_vecs)
fig = plt.scatter(x, y)

# %%
tmp_reshaped.shape, labels_1epoch_reshaped.shape
# Out:
# ((4800, 128, 2), (16, 128))

# %%
def save_feature_mapping(self, features, labels):
    if self.training: # Train mode
        two_vecs = model.two_vecs[-1].cpu().detach().numpy().copy()
        x, y = zip(*two_vecs)
        fig = plt.scatter(x, y)
        plt.savefig(fig)
    else: # Eval mode
        two_vecs = model.two_vecs[-1].cpu().detach().numpy().copy()
        x, y = zip(*two_vecs)
        fig = plt.scatter(x, y)
        plt.savefig(fig)

# %%
# from tsai.models.utils import count_parameters

# %%
class MyDataset(Dataset):
    def __init__(self, dataset, labels, root_dir, transform=None) -> None:
        # super().__init__()
        self.radar_heartbeat = dataset
        self.labels = labels
        self.root_dir = root_dir
        self.transform = transform

    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
          idx = idx.tolist()
        
        onehot_label = torch.eye(num_classes)[self.labels[idx] - 1] # one hot encodingは不要らしい　精度悪い場合試す必要あり
        # one_hot = torch.nn.functional.one_hot(self.labels, num_classes=num_classes)
        return torch.tensor(self.radar_heartbeat[idx]), self.labels[idx] # labels is already tensor (converted in preparation phase)
        # return torch.tensor(self.radar_heartbeat[idx]), onehot_label

    def __len__(self):
        return len(self.radar_heartbeat)


dataset = MyDataset(data_series, labels_tensor, "./data/", transform=transforms.ToTensor())

# %%
dataset[0][1], dataset[4473][1], dataset[4474][1], dataset[len(dataset)-1][1]
# Out:
# (tensor(0), tensor(15), tensor(15), tensor(15))

# %%
dataset[3570][1], dataset[3571][1]
# Out:
# (tensor(15), tensor(15))

# %%
dataset[2691][1], dataset[2692][1]
# Out:
# (tensor(14), tensor(15))

# %% [markdown]
# Additional processing for Open Set
#
# e.g.
# train 0~24
#
# test 0~30
#
# concat

# %%
# indices1 = np.arange(4473)
# dataset1 = torch.utils.data.Subset(dataset, indices1) # 0-24
# indices2 = np.arange(4474, len(dataset))
# dataset2 = torch.utils.data.Subset(dataset, indices2) # 25-30
# Unknown_label = close_num + 1

# %%
# indices1 = np.arange(3570)
# dataset1 = torch.utils.data.Subset(dataset, indices1) # 0-19
# indices2 = np.arange(3571, len(dataset))
# dataset2 = torch.utils.data.Subset(dataset, indices2) # 20-30
# Unknown_label = close_num + 1

# %%
indices1 = np.arange(2691)
dataset1 = torch.utils.data.Subset(dataset, indices1) # 0-14
indices2 = np.arange(2692, len(dataset))
dataset2 = torch.utils.data.Subset(dataset, indices2) # 15-29
Unknown_label = close_num + 1

# %%
train_size1 = int(0.80 * len(dataset1))
test_size1 = len(dataset1) - train_size1

train_size2 = int(0.80 * len(dataset2))
test_size2 = len(dataset2) - train_size2

open_train_set, test_set1 = torch.utils.data.random_split(dataset1, [train_size1, test_size1])
train_set2, test_set2 = torch.utils.data.random_split(dataset2, [train_size2, test_size2])

indices = np.arange(len(test_set2))
test_set2 = torch.utils.data.Subset(test_set2, indices[:])

# %% [markdown]
# train : test = 8 : 2 → 3 : 1で分ける

# %%
open_test_set = torch.utils.data.ConcatDataset([test_set1, test_set2])
len(open_train_set), len(open_test_set)
# Out:
# (2152, 1084)

# %%
train_loader = DataLoader(dataset=open_train_set, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=open_test_set, batch_size=batch_size, shuffle=True) # テストでシャッフルしても同じ、図示のためにshuffle

# %% [markdown]
# ## Triple Joint Loss

# %%
from torch import log
softmax = nn.Softmax()

def softmax_loss(outputs, labels):
    loss = 0
    batch_size = len(labels)
    logsoftmax_out = log(softmax(outputs))
    for idx in range(batch_size):
        loss += 1.0 - logsoftmax_out[idx][labels[idx]]
    
    return loss / batch_size


from center_loss import CenterLoss
center_loss = CenterLoss(num_classes=close_num + 1, feat_dim=close_num + 1, use_gpu=True) # 入出力が同じだと一見変な感じがするが，交差エントロピーと違ってcenterlossを使うと最初から決めていれば，モデルの出力サイズを必ずしもクラス数に一致させる必要がないからfeat_dimを任意に設定できる．
optimizer_centloss = torch.optim.SGD(center_loss.parameters(), lr=0.05)


class AngularPenaltySMLoss(nn.Module):

    def __init__(self, in_features, out_features, loss_type='cosface', eps=1e-7, s=None, m=None):
        '''
        Angular Penalty Softmax Loss
        Three 'loss_types' available: ['arcface', 'sphereface', 'cosface']
        These losses are described in the following papers: 
        
        ArcFace: https://arxiv.org/abs/1801.07698
        SphereFace: https://arxiv.org/abs/1704.08063
        CosFace/Ad Margin: https://arxiv.org/abs/1801.05599
        '''
        super(AngularPenaltySMLoss, self).__init__()
        loss_type = loss_type.lower()
        assert loss_type in  ['arcface', 'sphereface', 'cosface']
        if loss_type == 'arcface':
            self.s = 64.0 if not s else s
            self.m = 0.5 if not m else m
        if loss_type == 'sphereface':
            self.s = 64.0 if not s else s
            self.m = 1.35 if not m else m
        if loss_type == 'cosface':
            self.s = 32.0 if not s else s
            self.m = 0.2 if not m else m
        self.loss_type = loss_type
        self.in_features = in_features
        self.out_features = out_features
        self.fc = nn.Linear(in_features, out_features, bias=False)
        self.fc.to(device)
        self.eps = eps

    def forward(self, x, labels):
        '''
        input shape (N, in_features)
        '''
        assert len(x) == len(labels)
        assert torch.min(labels) >= 0
        assert torch.max(labels) < self.out_features
        
        for W in self.fc.parameters():
            W = F.normalize(W, p=2, dim=1)

        x = F.normalize(x, p=2, dim=1)
        # logを引き算に変えて計算
        wf = self.fc(x)
        if self.loss_type == 'cosface':
            numerator = self.s * (torch.diagonal(wf.transpose(0, 1)[labels]) - self.m)
        if self.loss_type == 'arcface':
            numerator = self.s * torch.cos(torch.acos(torch.clamp(torch.diagonal(wf.transpose(0, 1)[labels]), -1.+self.eps, 1-self.eps)) + self.m)
        if self.loss_type == 'sphereface':
            numerator = self.s * torch.cos(self.m * torch.acos(torch.clamp(torch.diagonal(wf.transpose(0, 1)[labels]), -1.+self.eps, 1-self.eps)))

        excl = torch.cat([torch.cat((wf[i, :y], wf[i, y+1:])).unsqueeze(0) for i, y in enumerate(labels)], dim=0)
        denominator = torch.exp(numerator) + torch.sum(torch.exp(self.s * excl), dim=1)
        L = numerator - torch.log(denominator)
        return -torch.mean(L)

cos_loss = AngularPenaltySMLoss(close_num + 1, close_num + 1, loss_type="cosface") # center_lossと同じ理由でin_featuresはクラス数でよい．


def triple_joint_loss(output, label, alpha):
    # alpha: hyper parameter
    output_only_truth = []
    for idx, x in enumerate(output):
        x = x[labels[idx]]
        x = torch.tensor(x).to(device)
        output_only_truth.append([x])
    output_only_truth = torch.tensor(output_only_truth)
    output_only_truth = output_only_truth.float()
    output_only_truth = output_only_truth.to(device)
    # print(output.is_cuda, output_only_truth.is_cuda, label.is_cuda)

    return softmax_loss(output, label)
    # return softmax_loss(output, label) + alpha * center_loss(output, label)
    # return softmax_loss(output, label) + alpha * center_loss(output, label) + cos_loss(output, label)
    # return cos_loss(output_only_truth, label)

# %%
model = InceptionTime(1, close_num + 1) # 0-?+Unknownを出力
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
model.train()
n_total_steps = len(train_loader)
for epoch in range(num_epochs):
  for i, (signals, labels) in enumerate(train_loader):
    signals = torch.tensor(signals)
    signals = signals.float()
    signals = signals.to(device)
    labels = labels.to(device)

    # print(signals.size())
    outputs = model(signals)
    outputs = outputs.to(device)
    # print(outputs)
    # loss = triple_joint_loss(outputs, labels, alpha) # will check the shapes of outputs and labels
    loss = criterion(outputs, labels)

    optimizer.zero_grad()
    # optimizer_centloss.zero_grad()
    loss.backward()
    # for param in center_loss.parameters():
    #   param.grad.data *= (1./alpha) # 98.98%を出したときはこれを書いていなかった→追加しても問題なし．
    optimizer.step()
    # optimizer_centloss.step()
    if (i + 1) % 12 == 0:
      print(f'Epoch [{epoch+1}/`{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')
# Out:
# /tmp/ipykernel_2321/503784539.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   signals = torch.tensor(signals)
# Epoch [1/`300], Step [12/34], Loss: 2.5389
# Epoch [1/`300], Step [24/34], Loss: 2.2490
# Epoch [2/`300], Step [12/34], Loss: 2.1463
# Epoch [2/`300], Step [24/34], Loss: 2.0910
# Epoch [3/`300], Step [12/34], Loss: 1.8101
# Epoch [3/`300], Step [24/34], Loss: 1.8010
# Epoch [4/`300], Step [12/34], Loss: 1.6306
# Epoch [4/`300], Step [24/34], Loss: 1.6829
# Epoch [5/`300], Step [12/34], Loss: 1.4827
# Epoch [5/`300], Step [24/34], Loss: 1.4780
# Epoch [6/`300], Step [12/34], Loss: 1.2987
# Epoch [6/`300], Step [24/34], Loss: 1.2502
# Epoch [7/`300], Step [12/34], Loss: 1.2092
# Epoch [7/`300], Step [24/34], Loss: 1.2767
# Epoch [8/`300], Step [12/34], Loss: 0.9113
# Epoch [8/`300], Step [24/34], Loss: 1.1165
# Epoch [9/`300], Step [12/34], Loss: 1.2271
# Epoch [9/`300], Step [24/34], Loss: 0.9582
# Epoch [10/`300], Step [12/34], Loss: 0.8156
# Epoch [10/`300], Step [24/34], Loss: 0.8268
# Epoch [11/`300], Step [12/34], Loss: 0.7991
# Epoch [11/`300], Step [24/34], Loss: 0.7789
# Epoch [12/`300], Step [12/34], Loss: 0.8189
# Epoch [12/`300], Step [24/34], Loss: 0.6749
# Epoch [13/`300], Step [12/34], Loss: 0.6381
# Epoch [13/`300], Step [24/34], Loss: 0.6023
# Epoch [14/`300], Step [12/34], Loss: 0.6586
# Epoch [14/`300], Step [24/34], Loss: 0.5434
# Epoch [15/`300], Step [12/34], Loss: 0.7415
# Epoch [15/`300], Step [24/34], Loss: 0.4527
# Epoch [16/`300], Step [12/34], Loss: 0.4363
# Epoch [16/`300], Step [24/34], Loss: 0.4590
# Epoch [17/`300], Step [12/34], Loss: 0.4597
# Epoch [17/`300], Step [24/34], Loss: 0.4771
# Epoch [18/`300], Step [12/34], Loss: 0.4866
# Epoch [18/`300], Step [24/34], Loss: 0.3901
# Epoch [19/`300], Step [12/34], Loss: 0.3847
# Epoch [19/`300], Step [24/34], Loss: 0.3450
# Epoch [20/`300], Step [12/34], Loss: 0.3413
# Epoch [20/`300], Step [24/34], Loss: 0.3437
# Epoch [21/`300], Step [12/34], Loss: 0.3294
# Epoch [21/`300], Step [24/34], Loss: 0.2936
# Epoch [22/`300], Step [12/34], Loss: 0.3701
# Epoch [22/`300], Step [24/34], Loss: 0.3199
# Epoch [23/`300], Step [12/34], Loss: 0.2416
# Epoch [23/`300], Step [24/34], Loss: 0.2491
# Epoch [24/`300], Step [12/34], Loss: 0.2446
# Epoch [24/`300], Step [24/34], Loss: 0.2235
# Epoch [25/`300], Step [12/34], Loss: 0.2738
# Epoch [25/`300], Step [24/34], Loss: 0.3314
# Epoch [26/`300], Step [12/34], Loss: 0.3019
# Epoch [26/`300], Step [24/34], Loss: 0.2264
# Epoch [27/`300], Step [12/34], Loss: 0.1952
# Epoch [27/`300], Step [24/34], Loss: 0.2375
# Epoch [28/`300], Step [12/34], Loss: 0.2052
# Epoch [28/`300], Step [24/34], Loss: 0.1790
# Epoch [29/`300], Step [12/34], Loss: 0.2561
# Epoch [29/`300], Step [24/34], Loss: 0.1545
# Epoch [30/`300], Step [12/34], Loss: 0.1673
# Epoch [30/`300], Step [24/34], Loss: 0.1614
# Epoch [31/`300], Step [12/34], Loss: 0.1578
# Epoch [31/`300], Step [24/34], Loss: 0.1328
# Epoch [32/`300], Step [12/34], Loss: 0.1422
# Epoch [32/`300], Step [24/34], Loss: 0.1126
# Epoch [33/`300], Step [12/34], Loss: 0.1394
# Epoch [33/`300], Step [24/34], Loss: 0.1219
# Epoch [34/`300], Step [12/34], Loss: 0.1227
# Epoch [34/`300], Step [24/34], Loss: 0.1082
# Epoch [35/`300], Step [12/34], Loss: 0.1866
# Epoch [35/`300], Step [24/34], Loss: 0.1293
# Epoch [36/`300], Step [12/34], Loss: 0.0731
# Epoch [36/`300], Step [24/34], Loss: 0.1114
# Epoch [37/`300], Step [12/34], Loss: 0.1535
# Epoch [37/`300], Step [24/34], Loss: 0.1419
# Epoch [38/`300], Step [12/34], Loss: 0.1021
# Epoch [38/`300], Step [24/34], Loss: 0.1491
# Epoch [39/`300], Step [12/34], Loss: 0.0887
# Epoch [39/`300], Step [24/34], Loss: 0.0909
# Epoch [40/`300], Step [12/34], Loss: 0.0737
# Epoch [40/`300], Step [24/34], Loss: 0.0958
# Epoch [41/`300], Step [12/34], Loss: 0.0891
# Epoch [41/`300], Step [24/34], Loss: 0.1048
# Epoch [42/`300], Step [12/34], Loss: 0.0930
# Epoch [42/`300], Step [24/34], Loss: 0.1204
# Epoch [43/`300], Step [12/34], Loss: 0.1307
# Epoch [43/`300], Step [24/34], Loss: 0.0970
# Epoch [44/`300], Step [12/34], Loss: 0.1052
# Epoch [44/`300], Step [24/34], Loss: 0.1226
# Epoch [45/`300], Step [12/34], Loss: 0.0670
# Epoch [45/`300], Step [24/34], Loss: 0.0708
# Epoch [46/`300], Step [12/34], Loss: 0.0470
# Epoch [46/`300], Step [24/34], Loss: 0.0640
# Epoch [47/`300], Step [12/34], Loss: 0.0858
# Epoch [47/`300], Step [24/34], Loss: 0.0441
# Epoch [48/`300], Step [12/34], Loss: 0.0692
# Epoch [48/`300], Step [24/34], Loss: 0.0595
# Epoch [49/`300], Step [12/34], Loss: 0.0496
# Epoch [49/`300], Step [24/34], Loss: 0.0554
# Epoch [50/`300], Step [12/34], Loss: 0.0731
# Epoch [50/`300], Step [24/34], Loss: 0.0497
# Epoch [51/`300], Step [12/34], Loss: 0.0544
# Epoch [51/`300], Step [24/34], Loss: 0.0385
# Epoch [52/`300], Step [12/34], Loss: 0.0701
# Epoch [52/`300], Step [24/34], Loss: 0.0668
# Epoch [53/`300], Step [12/34], Loss: 0.0382
# Epoch [53/`300], Step [24/34], Loss: 0.0421
# Epoch [54/`300], Step [12/34], Loss: 0.0358
# Epoch [54/`300], Step [24/34], Loss: 0.0454
# Epoch [55/`300], Step [12/34], Loss: 0.0484
# Epoch [55/`300], Step [24/34], Loss: 0.0429
# Epoch [56/`300], Step [12/34], Loss: 0.0426
# Epoch [56/`300], Step [24/34], Loss: 0.0516
# Epoch [57/`300], Step [12/34], Loss: 0.0420
# Epoch [57/`300], Step [24/34], Loss: 0.0636
# Epoch [58/`300], Step [12/34], Loss: 0.0547
# Epoch [58/`300], Step [24/34], Loss: 0.0558
# Epoch [59/`300], Step [12/34], Loss: 0.0735
# Epoch [59/`300], Step [24/34], Loss: 0.0314
# Epoch [87/`300], Step [24/34], Loss: 0.0162
# Epoch [88/`300], Step [12/34], Loss: 0.0145
# Epoch [88/`300], Step [24/34], Loss: 0.0142
# Epoch [89/`300], Step [12/34], Loss: 0.0134
# Epoch [89/`300], Step [24/34], Loss: 0.0184
# Epoch [90/`300], Step [12/34], Loss: 0.0100
# Epoch [90/`300], Step [24/34], Loss: 0.0256
# Epoch [91/`300], Step [12/34], Loss: 0.0137
# Epoch [91/`300], Step [24/34], Loss: 0.0130
# Epoch [92/`300], Step [12/34], Loss: 0.0161
# Epoch [92/`300], Step [24/34], Loss: 0.0074
# Epoch [93/`300], Step [12/34], Loss: 0.0087
# Epoch [93/`300], Step [24/34], Loss: 0.0135
# Epoch [94/`300], Step [12/34], Loss: 0.0077
# Epoch [94/`300], Step [24/34], Loss: 0.0067
# Epoch [95/`300], Step [12/34], Loss: 0.0106
# Epoch [95/`300], Step [24/34], Loss: 0.0065
# Epoch [96/`300], Step [12/34], Loss: 0.0208
# Epoch [96/`300], Step [24/34], Loss: 0.0116
# Epoch [97/`300], Step [12/34], Loss: 0.0147
# Epoch [97/`300], Step [24/34], Loss: 0.0095
# Epoch [98/`300], Step [12/34], Loss: 0.0126
# Epoch [98/`300], Step [24/34], Loss: 0.0082
# Epoch [99/`300], Step [12/34], Loss: 0.0098
# Epoch [99/`300], Step [24/34], Loss: 0.0100
# Epoch [100/`300], Step [12/34], Loss: 0.0092
# Epoch [100/`300], Step [24/34], Loss: 0.0071
# Epoch [101/`300], Step [12/34], Loss: 0.0065
# Epoch [101/`300], Step [24/34], Loss: 0.0064
# Epoch [102/`300], Step [12/34], Loss: 0.0147
# Epoch [102/`300], Step [24/34], Loss: 0.0083
# Epoch [103/`300], Step [12/34], Loss: 0.0115
# Epoch [103/`300], Step [24/34], Loss: 0.0117
# Epoch [104/`300], Step [12/34], Loss: 0.0075
# Epoch [104/`300], Step [24/34], Loss: 0.0099
# Epoch [105/`300], Step [12/34], Loss: 0.0104
# Epoch [105/`300], Step [24/34], Loss: 0.0112
# Epoch [106/`300], Step [12/34], Loss: 0.0115
# Epoch [106/`300], Step [24/34], Loss: 0.0082
# Epoch [107/`300], Step [12/34], Loss: 0.0077
# Epoch [107/`300], Step [24/34], Loss: 0.0047
# Epoch [108/`300], Step [12/34], Loss: 0.0081
# Epoch [108/`300], Step [24/34], Loss: 0.0095
# Epoch [109/`300], Step [12/34], Loss: 0.0077
# Epoch [109/`300], Step [24/34], Loss: 0.0074
# Epoch [110/`300], Step [12/34], Loss: 0.0050
# Epoch [110/`300], Step [24/34], Loss: 0.0104
# Epoch [111/`300], Step [12/34], Loss: 0.0094
# Epoch [111/`300], Step [24/34], Loss: 0.0102
# Epoch [112/`300], Step [12/34], Loss: 0.0136
# Epoch [112/`300], Step [24/34], Loss: 0.0125
# Epoch [113/`300], Step [12/34], Loss: 0.0110
# Epoch [113/`300], Step [24/34], Loss: 0.0090
# Epoch [114/`300], Step [12/34], Loss: 0.0039
# Epoch [114/`300], Step [24/34], Loss: 0.0051
# Epoch [115/`300], Step [12/34], Loss: 0.0058
# Epoch [115/`300], Step [24/34], Loss: 0.0070
# Epoch [116/`300], Step [12/34], Loss: 0.0082
# Epoch [116/`300], Step [24/34], Loss: 0.0091
# Epoch [117/`300], Step [12/34], Loss: 0.0112
# Epoch [117/`300], Step [24/34], Loss: 0.0085
# Epoch [118/`300], Step [12/34], Loss: 0.0060
# Epoch [118/`300], Step [24/34], Loss: 0.0051
# Epoch [119/`300], Step [12/34], Loss: 0.0064
# Epoch [119/`300], Step [24/34], Loss: 0.0032
# Epoch [120/`300], Step [12/34], Loss: 0.0131
# Epoch [120/`300], Step [24/34], Loss: 0.0045
# Epoch [121/`300], Step [12/34], Loss: 0.0046
# Epoch [121/`300], Step [24/34], Loss: 0.0045
# Epoch [122/`300], Step [12/34], Loss: 0.0039
# Epoch [122/`300], Step [24/34], Loss: 0.0056
# Epoch [123/`300], Step [12/34], Loss: 0.0050
# Epoch [123/`300], Step [24/34], Loss: 0.0083
# Epoch [124/`300], Step [12/34], Loss: 0.0030
# Epoch [124/`300], Step [24/34], Loss: 0.0049
# Epoch [125/`300], Step [12/34], Loss: 0.0051
# Epoch [125/`300], Step [24/34], Loss: 0.0061
# Epoch [126/`300], Step [12/34], Loss: 0.0047
# Epoch [126/`300], Step [24/34], Loss: 0.0044
# Epoch [127/`300], Step [12/34], Loss: 0.0038
# Epoch [127/`300], Step [24/34], Loss: 0.0026
# Epoch [128/`300], Step [12/34], Loss: 0.0040
# Epoch [128/`300], Step [24/34], Loss: 0.0084
# Epoch [129/`300], Step [12/34], Loss: 0.0464
# Epoch [129/`300], Step [24/34], Loss: 0.0709
# Epoch [130/`300], Step [12/34], Loss: 0.0223
# Epoch [130/`300], Step [24/34], Loss: 0.0200
# Epoch [131/`300], Step [12/34], Loss: 0.0147
# Epoch [131/`300], Step [24/34], Loss: 0.0159
# Epoch [132/`300], Step [12/34], Loss: 0.0065
# Epoch [132/`300], Step [24/34], Loss: 0.0099
# Epoch [133/`300], Step [12/34], Loss: 0.0075
# Epoch [133/`300], Step [24/34], Loss: 0.0062
# Epoch [134/`300], Step [12/34], Loss: 0.0047
# Epoch [134/`300], Step [24/34], Loss: 0.0059
# Epoch [135/`300], Step [12/34], Loss: 0.0041
# Epoch [135/`300], Step [24/34], Loss: 0.0043
# Epoch [136/`300], Step [12/34], Loss: 0.0039
# Epoch [136/`300], Step [24/34], Loss: 0.0039
# Epoch [137/`300], Step [12/34], Loss: 0.0067
# Epoch [137/`300], Step [24/34], Loss: 0.0047
# Epoch [138/`300], Step [12/34], Loss: 0.0044
# Epoch [138/`300], Step [24/34], Loss: 0.0054
# Epoch [139/`300], Step [12/34], Loss: 0.0038
# Epoch [139/`300], Step [24/34], Loss: 0.0034
# Epoch [140/`300], Step [12/34], Loss: 0.0030
# Epoch [140/`300], Step [24/34], Loss: 0.0040
# Epoch [141/`300], Step [12/34], Loss: 0.0098
# Epoch [141/`300], Step [24/34], Loss: 0.0126
# Epoch [142/`300], Step [12/34], Loss: 0.0024
# Epoch [142/`300], Step [24/34], Loss: 0.0066
# Epoch [143/`300], Step [12/34], Loss: 0.0077
# Epoch [143/`300], Step [24/34], Loss: 0.0017
# Epoch [144/`300], Step [12/34], Loss: 0.0021
# Epoch [144/`300], Step [24/34], Loss: 0.0034
# Epoch [145/`300], Step [12/34], Loss: 0.0022
# Epoch [145/`300], Step [24/34], Loss: 0.0032
# Epoch [146/`300], Step [12/34], Loss: 0.0032
# Epoch [146/`300], Step [24/34], Loss: 0.0038
# Epoch [147/`300], Step [12/34], Loss: 0.0031
# Epoch [147/`300], Step [24/34], Loss: 0.0021
# Epoch [148/`300], Step [12/34], Loss: 0.0027
# Epoch [148/`300], Step [24/34], Loss: 0.0039
# Epoch [149/`300], Step [12/34], Loss: 0.0026
# Epoch [149/`300], Step [24/34], Loss: 0.0020
# Epoch [150/`300], Step [12/34], Loss: 0.0027
# Epoch [150/`300], Step [24/34], Loss: 0.0029
# Epoch [151/`300], Step [12/34], Loss: 0.0034
# Epoch [151/`300], Step [24/34], Loss: 0.0050
# Epoch [152/`300], Step [12/34], Loss: 0.0134
# Epoch [152/`300], Step [24/34], Loss: 0.0017
# Epoch [153/`300], Step [12/34], Loss: 0.0021
# Epoch [153/`300], Step [24/34], Loss: 0.0109
# Epoch [154/`300], Step [12/34], Loss: 0.0019
# Epoch [154/`300], Step [24/34], Loss: 0.0017
# Epoch [155/`300], Step [12/34], Loss: 0.0024
# Epoch [155/`300], Step [24/34], Loss: 0.0041
# Epoch [156/`300], Step [12/34], Loss: 0.0025
# Epoch [156/`300], Step [24/34], Loss: 0.0040
# Epoch [157/`300], Step [12/34], Loss: 0.0021
# Epoch [157/`300], Step [24/34], Loss: 0.0020
# Epoch [158/`300], Step [12/34], Loss: 0.0069
# Epoch [158/`300], Step [24/34], Loss: 0.0033
# Epoch [159/`300], Step [12/34], Loss: 0.0018
# Epoch [159/`300], Step [24/34], Loss: 0.0024
# Epoch [160/`300], Step [12/34], Loss: 0.0014
# Epoch [160/`300], Step [24/34], Loss: 0.0016
# Epoch [161/`300], Step [12/34], Loss: 0.0040
# Epoch [161/`300], Step [24/34], Loss: 0.0012
# Epoch [162/`300], Step [12/34], Loss: 0.0020
# Epoch [162/`300], Step [24/34], Loss: 0.0017
# Epoch [163/`300], Step [12/34], Loss: 0.0030
# Epoch [163/`300], Step [24/34], Loss: 0.0018
# Epoch [164/`300], Step [12/34], Loss: 0.0017
# Epoch [164/`300], Step [24/34], Loss: 0.0023
# Epoch [165/`300], Step [12/34], Loss: 0.0017
# Epoch [165/`300], Step [24/34], Loss: 0.0015
# Epoch [166/`300], Step [12/34], Loss: 0.0031
# Epoch [166/`300], Step [24/34], Loss: 0.0017
# Epoch [167/`300], Step [12/34], Loss: 0.0013
# Epoch [167/`300], Step [24/34], Loss: 0.0010
# Epoch [168/`300], Step [12/34], Loss: 0.0019
# Epoch [168/`300], Step [24/34], Loss: 0.0013
# Epoch [169/`300], Step [12/34], Loss: 0.0014
# Epoch [169/`300], Step [24/34], Loss: 0.0013
# Epoch [170/`300], Step [12/34], Loss: 0.0010
# Epoch [170/`300], Step [24/34], Loss: 0.0017
# Epoch [171/`300], Step [12/34], Loss: 0.0024
# Epoch [171/`300], Step [24/34], Loss: 0.0014
# Epoch [172/`300], Step [12/34], Loss: 0.0017
# Epoch [172/`300], Step [24/34], Loss: 0.0008
# Epoch [173/`300], Step [12/34], Loss: 0.0012
# Epoch [173/`300], Step [24/34], Loss: 0.0017
# Epoch [174/`300], Step [12/34], Loss: 0.0015
# Epoch [174/`300], Step [24/34], Loss: 0.0013
# Epoch [175/`300], Step [12/34], Loss: 0.0014
# Epoch [175/`300], Step [24/34], Loss: 0.0010
# Epoch [176/`300], Step [12/34], Loss: 0.0014
# Epoch [176/`300], Step [24/34], Loss: 0.0021
# Epoch [177/`300], Step [12/34], Loss: 0.0025
# Epoch [177/`300], Step [24/34], Loss: 0.0013
# Epoch [178/`300], Step [12/34], Loss: 0.0019
# Epoch [178/`300], Step [24/34], Loss: 0.0011
# Epoch [179/`300], Step [12/34], Loss: 0.0017
# Epoch [179/`300], Step [24/34], Loss: 0.0023
# Epoch [180/`300], Step [12/34], Loss: 0.0015
# Epoch [180/`300], Step [24/34], Loss: 0.0035
# Epoch [181/`300], Step [12/34], Loss: 0.0008
# Epoch [181/`300], Step [24/34], Loss: 0.0012
# Epoch [182/`300], Step [12/34], Loss: 0.0020
# Epoch [182/`300], Step [24/34], Loss: 0.0015
# Epoch [183/`300], Step [12/34], Loss: 0.0014
# Epoch [183/`300], Step [24/34], Loss: 0.0016
# Epoch [184/`300], Step [12/34], Loss: 0.0016
# Epoch [184/`300], Step [24/34], Loss: 0.0012
# Epoch [185/`300], Step [12/34], Loss: 0.0012
# Epoch [185/`300], Step [24/34], Loss: 0.0015
# Epoch [186/`300], Step [12/34], Loss: 0.0013
# Epoch [186/`300], Step [24/34], Loss: 0.0013
# Epoch [187/`300], Step [12/34], Loss: 0.0034
# Epoch [187/`300], Step [24/34], Loss: 0.0030
# Epoch [188/`300], Step [12/34], Loss: 0.0016
# Epoch [188/`300], Step [24/34], Loss: 0.0007
# Epoch [189/`300], Step [12/34], Loss: 0.0017
# Epoch [189/`300], Step [24/34], Loss: 0.0013
# Epoch [190/`300], Step [12/34], Loss: 0.0009
# Epoch [190/`300], Step [24/34], Loss: 0.0008
# Epoch [191/`300], Step [12/34], Loss: 0.0035
# Epoch [191/`300], Step [24/34], Loss: 0.0008
# Epoch [192/`300], Step [12/34], Loss: 0.0035
# Epoch [192/`300], Step [24/34], Loss: 0.0015
# Epoch [193/`300], Step [12/34], Loss: 0.0011
# Epoch [193/`300], Step [24/34], Loss: 0.0019
# Epoch [194/`300], Step [12/34], Loss: 0.0008
# Epoch [194/`300], Step [24/34], Loss: 0.0011
# Epoch [195/`300], Step [12/34], Loss: 0.0011
# Epoch [195/`300], Step [24/34], Loss: 0.0034
# Epoch [196/`300], Step [12/34], Loss: 0.0009
# Epoch [196/`300], Step [24/34], Loss: 0.0014
# Epoch [197/`300], Step [12/34], Loss: 0.0010
# Epoch [197/`300], Step [24/34], Loss: 0.0013
# Epoch [198/`300], Step [12/34], Loss: 0.0022
# Epoch [198/`300], Step [24/34], Loss: 0.0111
# Epoch [199/`300], Step [12/34], Loss: 0.0649
# Epoch [199/`300], Step [24/34], Loss: 0.0998
# Epoch [200/`300], Step [12/34], Loss: 0.0124
# Epoch [200/`300], Step [24/34], Loss: 0.0128
# Epoch [201/`300], Step [12/34], Loss: 0.0400
# Epoch [201/`300], Step [24/34], Loss: 0.0049
# Epoch [202/`300], Step [12/34], Loss: 0.0062
# Epoch [202/`300], Step [24/34], Loss: 0.0028
# Epoch [203/`300], Step [12/34], Loss: 0.0046
# Epoch [203/`300], Step [24/34], Loss: 0.0020
# Epoch [204/`300], Step [12/34], Loss: 0.0031
# Epoch [204/`300], Step [24/34], Loss: 0.0041
# Epoch [205/`300], Step [12/34], Loss: 0.0016
# Epoch [205/`300], Step [24/34], Loss: 0.0021
# Epoch [206/`300], Step [12/34], Loss: 0.0039
# Epoch [206/`300], Step [24/34], Loss: 0.0023
# Epoch [207/`300], Step [12/34], Loss: 0.0016
# Epoch [207/`300], Step [24/34], Loss: 0.0018
# Epoch [208/`300], Step [12/34], Loss: 0.0014
# Epoch [208/`300], Step [24/34], Loss: 0.0017
# Epoch [209/`300], Step [12/34], Loss: 0.0021
# Epoch [209/`300], Step [24/34], Loss: 0.0061
# Epoch [210/`300], Step [12/34], Loss: 0.0016
# Epoch [210/`300], Step [24/34], Loss: 0.0010
# Epoch [211/`300], Step [12/34], Loss: 0.0013
# Epoch [211/`300], Step [24/34], Loss: 0.0027
# Epoch [212/`300], Step [12/34], Loss: 0.0023
# Epoch [212/`300], Step [24/34], Loss: 0.0021
# Epoch [213/`300], Step [12/34], Loss: 0.0017
# Epoch [213/`300], Step [24/34], Loss: 0.0017
# Epoch [214/`300], Step [12/34], Loss: 0.0018
# Epoch [214/`300], Step [24/34], Loss: 0.0008
# Epoch [215/`300], Step [12/34], Loss: 0.0044
# Epoch [215/`300], Step [24/34], Loss: 0.0021
# Epoch [216/`300], Step [12/34], Loss: 0.0014
# Epoch [216/`300], Step [24/34], Loss: 0.0011
# Epoch [217/`300], Step [12/34], Loss: 0.0018
# Epoch [217/`300], Step [24/34], Loss: 0.0009
# Epoch [218/`300], Step [12/34], Loss: 0.0010
# Epoch [218/`300], Step [24/34], Loss: 0.0015
# Epoch [219/`300], Step [12/34], Loss: 0.0009
# Epoch [219/`300], Step [24/34], Loss: 0.0019
# Epoch [220/`300], Step [12/34], Loss: 0.0009
# Epoch [220/`300], Step [24/34], Loss: 0.0007
# Epoch [221/`300], Step [12/34], Loss: 0.0008
# Epoch [221/`300], Step [24/34], Loss: 0.0010
# Epoch [222/`300], Step [12/34], Loss: 0.0008
# Epoch [222/`300], Step [24/34], Loss: 0.0007
# Epoch [223/`300], Step [12/34], Loss: 0.0025
# Epoch [223/`300], Step [24/34], Loss: 0.0013
# Epoch [251/`300], Step [24/34], Loss: 0.0005
# Epoch [252/`300], Step [12/34], Loss: 0.0006
# Epoch [252/`300], Step [24/34], Loss: 0.0007
# Epoch [253/`300], Step [12/34], Loss: 0.0007
# Epoch [253/`300], Step [24/34], Loss: 0.0003
# Epoch [254/`300], Step [12/34], Loss: 0.0007
# Epoch [254/`300], Step [24/34], Loss: 0.0006
# Epoch [255/`300], Step [12/34], Loss: 0.0003
# Epoch [255/`300], Step [24/34], Loss: 0.0004
# Epoch [256/`300], Step [12/34], Loss: 0.0002
# Epoch [256/`300], Step [24/34], Loss: 0.0003
# Epoch [257/`300], Step [12/34], Loss: 0.0009
# Epoch [257/`300], Step [24/34], Loss: 0.0007
# Epoch [258/`300], Step [12/34], Loss: 0.0006
# Epoch [258/`300], Step [24/34], Loss: 0.0006
# Epoch [259/`300], Step [12/34], Loss: 0.0005
# Epoch [259/`300], Step [24/34], Loss: 0.0003
# Epoch [260/`300], Step [12/34], Loss: 0.0012
# Epoch [260/`300], Step [24/34], Loss: 0.0005
# Epoch [261/`300], Step [12/34], Loss: 0.0006
# Epoch [261/`300], Step [24/34], Loss: 0.0009
# Epoch [262/`300], Step [12/34], Loss: 0.0004
# Epoch [262/`300], Step [24/34], Loss: 0.0003
# Epoch [263/`300], Step [12/34], Loss: 0.0004
# Epoch [263/`300], Step [24/34], Loss: 0.0004
# Epoch [264/`300], Step [12/34], Loss: 0.0003
# Epoch [264/`300], Step [24/34], Loss: 0.0003
# Epoch [265/`300], Step [12/34], Loss: 0.0002
# Epoch [265/`300], Step [24/34], Loss: 0.0003
# Epoch [266/`300], Step [12/34], Loss: 0.0003
# Epoch [266/`300], Step [24/34], Loss: 0.0003
# Epoch [267/`300], Step [12/34], Loss: 0.0005
# Epoch [267/`300], Step [24/34], Loss: 0.0005
# Epoch [268/`300], Step [12/34], Loss: 0.0002
# Epoch [268/`300], Step [24/34], Loss: 0.0004
# Epoch [269/`300], Step [12/34], Loss: 0.0002
# Epoch [269/`300], Step [24/34], Loss: 0.0005
# Epoch [270/`300], Step [12/34], Loss: 0.0005
# Epoch [270/`300], Step [24/34], Loss: 0.0004
# Epoch [271/`300], Step [12/34], Loss: 0.0003
# Epoch [271/`300], Step [24/34], Loss: 0.0004
# Epoch [272/`300], Step [12/34], Loss: 0.0004
# Epoch [272/`300], Step [24/34], Loss: 0.0006
# Epoch [273/`300], Step [12/34], Loss: 0.0004
# Epoch [273/`300], Step [24/34], Loss: 0.0012
# Epoch [274/`300], Step [12/34], Loss: 0.0003
# Epoch [274/`300], Step [24/34], Loss: 0.0003
# Epoch [275/`300], Step [12/34], Loss: 0.0003
# Epoch [275/`300], Step [24/34], Loss: 0.0002
# Epoch [276/`300], Step [12/34], Loss: 0.0002
# Epoch [276/`300], Step [24/34], Loss: 0.0003
# Epoch [277/`300], Step [12/34], Loss: 0.0002
# Epoch [277/`300], Step [24/34], Loss: 0.0007
# Epoch [278/`300], Step [12/34], Loss: 0.0003
# Epoch [278/`300], Step [24/34], Loss: 0.0003
# Epoch [279/`300], Step [12/34], Loss: 0.0004
# Epoch [279/`300], Step [24/34], Loss: 0.0003
# Epoch [280/`300], Step [12/34], Loss: 0.0003
# Epoch [280/`300], Step [24/34], Loss: 0.0005
# Epoch [281/`300], Step [12/34], Loss: 0.0002
# Epoch [281/`300], Step [24/34], Loss: 0.0003
# Epoch [282/`300], Step [12/34], Loss: 0.0002
# Epoch [282/`300], Step [24/34], Loss: 0.0004
# Epoch [283/`300], Step [12/34], Loss: 0.0007
# Epoch [283/`300], Step [24/34], Loss: 0.0003
# Epoch [284/`300], Step [12/34], Loss: 0.0001
# Epoch [284/`300], Step [24/34], Loss: 0.0002
# Epoch [285/`300], Step [12/34], Loss: 0.0004
# Epoch [285/`300], Step [24/34], Loss: 0.0002
# Epoch [286/`300], Step [12/34], Loss: 0.0004
# Epoch [286/`300], Step [24/34], Loss: 0.0002
# Epoch [287/`300], Step [12/34], Loss: 0.0002
# Epoch [287/`300], Step [24/34], Loss: 0.0001
# Epoch [288/`300], Step [12/34], Loss: 0.0002
# Epoch [288/`300], Step [24/34], Loss: 0.0002
# Epoch [289/`300], Step [12/34], Loss: 0.0001
# Epoch [289/`300], Step [24/34], Loss: 0.0005
# Epoch [290/`300], Step [12/34], Loss: 0.0003
# Epoch [290/`300], Step [24/34], Loss: 0.0008
# Epoch [291/`300], Step [12/34], Loss: 0.0001
# Epoch [291/`300], Step [24/34], Loss: 0.0002
# Epoch [292/`300], Step [12/34], Loss: 0.0001
# Epoch [292/`300], Step [24/34], Loss: 0.0002
# Epoch [293/`300], Step [12/34], Loss: 0.0001
# Epoch [293/`300], Step [24/34], Loss: 0.0003
# Epoch [294/`300], Step [12/34], Loss: 0.0002
# Epoch [294/`300], Step [24/34], Loss: 0.0001
# Epoch [295/`300], Step [12/34], Loss: 0.0001
# Epoch [295/`300], Step [24/34], Loss: 0.0001
# Epoch [296/`300], Step [12/34], Loss: 0.0001
# Epoch [296/`300], Step [24/34], Loss: 0.0003
# Epoch [297/`300], Step [12/34], Loss: 0.0002
# Epoch [297/`300], Step [24/34], Loss: 0.0001
# Epoch [298/`300], Step [12/34], Loss: 0.0002
# Epoch [298/`300], Step [24/34], Loss: 0.0014
# Epoch [299/`300], Step [12/34], Loss: 0.0004
# Epoch [299/`300], Step [24/34], Loss: 0.0002
# Epoch [300/`300], Step [12/34], Loss: 0.0003
# Epoch [300/`300], Step [24/34], Loss: 0.0004

# %% [markdown]
# labelは0-24までだから，学習はいじらなくて大丈夫
#
# testはOpen setの場合，0~24とUnknown label(25)になるから，labelは作り直し
#
# 25も出力するようなネットワークにしなきゃだめ

# %%
threshold = 0.65

# %%
# For Confusion Matrix
predicted_lists = np.zeros(0, dtype=np.int64)
one_hot_labels_list = np.zeros(0, dtype=np.int64)
model.eval()

with torch.no_grad():
  n_correct = 0
  n_samples = 0
  softmax = nn.Softmax()
  for i, (signals, one_hot_labels) in enumerate(test_loader):
    signals = torch.tensor(signals)
    signals = signals.float()
    signals = signals.to(device)
    one_hot_labels = one_hot_labels.to(device)
    # print(len(one_hot_labels))
    outputs = model(signals)
    if i == 1:
      print(outputs)
    for j, out in enumerate(outputs):
      outputs[j] = softmax(out)

    _, predicted = torch.max(outputs.data, 1) # predicted per batch size
    
    
    for idx in range(len(_)):
      if _[idx] < threshold:
        predicted[idx] = Unknown_label # 15, 20, 25
    print(_, predicted, one_hot_labels)

    n_samples += one_hot_labels.size(0) # add batch_size
    n_correct += (predicted == one_hot_labels).sum().item()
    
    predicted_cp = predicted.to('cpu').detach().numpy().copy()
    one_hot_labels_cp = one_hot_labels.to('cpu').detach().numpy().copy()
    predicted_lists = np.concatenate([predicted_lists, predicted_cp])
    one_hot_labels_list = np.concatenate([one_hot_labels_list, one_hot_labels_cp])
    
    acc = 100.0 * n_correct / n_samples
    print(f'{n_correct} / {n_samples} = Acc: {acc} %')
# Out:
# /tmp/ipykernel_2321/662945970.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   signals = torch.tensor(signals)
# /home/riku/workspace/InceptionTime/env/lib/python3.8/site-packages/torch/overrides.py:1534: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   result = torch_func_method(public_api, types, args, kwargs)
# TensorBase([0.2203, 0.5071, 0.9999, 0.2597, 1.0000, 0.9083, 0.5734, 1.0000,
#             1.0000, 0.3351, 0.1394, 0.9994, 1.0000, 0.4449, 0.9997, 0.5395,
#             0.8739, 0.2647, 0.4375, 0.4386, 0.9986, 0.9999, 0.9997, 0.9985,
#             1.0000, 0.4197, 0.9996, 0.2923, 1.0000, 0.9993, 0.9898, 0.4338,
#             1.0000, 0.9991, 0.9995, 0.4772, 0.8552, 0.4951, 0.9998, 0.9706,
#             0.5269, 0.9986, 0.4700, 0.6754, 0.9094, 0.9983, 1.0000, 1.0000,
#             0.3966, 0.9993, 0.8630, 0.6188, 0.9985, 0.9997, 0.9999, 0.3261,
#             0.9998, 0.3469, 0.4693, 0.7031, 0.4790, 0.8076, 1.0000, 0.4307],
#            device='cuda:0') TensorBase([15, 15,  0, 15,  5, 10, 15,  7,  6, 15, 15,  6, 11, 15,  5, 15,  4,
#             15, 15, 15,  4,  3, 11,  2,  4, 15,  4, 15, 11, 12,  1, 15,  3,  4,
#              8, 15,  0, 15, 14,  5, 15, 12, 15, 13,  2,  2,  2, 11, 15,  5, 10,
#             15,  0,  5,  4, 15, 10, 15, 15, 10, 15, 14,  7, 15],
#            device='cuda:0') tensor([15, 15,  0, 15,  5, 15, 15,  7,  6, 15, 15,  6, 11, 15,  5, 15, 15, 15,
#         15, 15,  4,  3, 11,  2,  4, 15,  4, 15, 11, 12,  1, 15,  3,  4,  8, 15,
#         15, 15, 14,  5, 15, 12, 15, 15, 15,  2,  2, 11, 15,  5, 15, 15,  0,  5,
#          4, 15, 10, 15, 15, 15, 15, 15,  7, 15], device='cuda:0')
# 56 / 64 = Acc: 87.5 %
# TensorBase([[-6.2732e+00, -3.3653e+00, -1.5889e+00, -3.4591e+00, -3.7057e+00,
#              -4.0242e+00, -5.1902e+00, -3.6096e+00, -3.4029e+00, -3.3593e+00,
#              -4.1769e+00, -5.0558e+00, -3.1554e+00,  1.0584e+01, -3.0684e-01],
#             0.4122, 0.9964, 1.0000, 0.8478, 0.9998, 0.9997, 0.9998, 0.9994,
#             0.6517, 0.7267, 0.2982, 0.6397, 0.5276, 0.6419, 0.9998, 0.9990],
#            device='cuda:0') TensorBase([15, 15,  5, 15,  4,  0, 10,  4,  3, 14, 13, 13, 14, 14,  1, 12,  0,
#             15, 15, 15,  3, 15, 14,  8, 15,  2, 14,  5, 15,  8,  0,  9, 11, 10,
#             14,  0, 10,  8, 14,  3, 14, 15,  3,  7,  9, 12, 15, 15, 15, 10,  6,
#             14,  9,  2,  9,  9, 14,  2, 15, 15, 15, 15,  1, 11],
#            device='cuda:0') tensor([15, 15,  5, 15,  4,  0, 15,  4,  3, 14, 13, 13, 14, 14,  1, 12,  0, 15,
#         15, 15,  3, 15, 14,  8, 15, 15, 14,  5, 15,  8,  0,  9, 11, 10, 15,  0,
#         10,  8, 15,  3, 14, 15,  3,  7, 15, 12, 15, 15, 15, 10,  6, 15,  9,  2,
#          9,  9, 15, 15, 15, 15, 15, 15,  1, 11], device='cuda:0')
# 378 / 448 = Acc: 84.375 %
# TensorBase([0.9998, 0.2798, 0.4781, 1.0000, 1.0000, 1.0000, 0.9998, 0.5499,
#             0.9994, 0.9999, 1.0000, 0.3366, 0.4264, 1.0000, 1.0000, 1.0000,
#             0.9992, 0.9998, 0.5083, 0.9999, 0.5975, 0.4194, 0.3794, 0.9994,
#             0.9999, 1.0000, 0.6832, 0.3360, 0.9998, 0.7728, 0.9997, 0.3144,
#             0.4170, 0.5074, 0.4978, 0.9990, 0.9999, 0.9999, 1.0000, 0.9994,
#             0.9912, 0.3317, 0.9992, 0.6084, 0.6848, 0.9996, 0.4814, 0.9997,
#             0.2390, 0.2020, 0.6995, 0.5175, 0.5980, 0.6325, 0.5265, 1.0000,
#             0.6894, 0.7180, 0.7429, 0.7363, 0.9966, 0.6688, 0.9998, 1.0000],
#            device='cuda:0') TensorBase([ 9, 15, 15,  3, 10,  3, 12, 15,  1,  7,  2, 15, 15, 11,  3, 13,  2,
#              0, 15,  0, 15, 15, 15,  1, 13,  2, 10, 15,  7,  2, 10, 15, 15, 15,
#             15,  0,  7,  9,  2,  1,  7, 15,  7, 15, 14,  0, 15,  4, 15, 15, 14,
#             15, 15, 15, 15,  8,  8, 13, 14,  8,  4, 13,  9,  3],
#            device='cuda:0') tensor([ 9, 15, 15,  3, 10,  3, 12, 15,  1,  7,  2, 15, 15, 11,  3, 13,  2,  0,
#         15,  0, 15, 15, 15,  1, 13,  2, 15, 15,  7, 15, 10, 15, 15, 15, 15,  0,
#          7,  9,  2,  1,  7, 15,  7, 15, 15,  0, 15,  4, 15, 15, 15, 15, 15, 15,
#         15,  8, 15, 15, 15, 15,  4, 15,  9,  3], device='cuda:0')
# 433 / 512 = Acc: 84.5703125 %
# TensorBase([0.3653, 0.4679, 0.9999, 0.6566, 0.3497, 1.0000, 0.9999, 0.9990,
#             0.5992, 0.4283, 1.0000, 0.5888, 0.9993, 1.0000, 0.5109, 0.9998,
#             0.9999, 0.9574, 1.0000, 0.4502, 0.6591, 1.0000, 0.9999, 0.9998,
#             0.4255, 0.6876, 0.4013, 0.7765, 1.0000, 1.0000, 0.9999, 0.9999,
#             1.0000, 0.9998, 0.9999, 0.5255, 1.0000, 0.8405, 0.4195, 0.9998,
#             0.6040, 0.6662, 0.5898, 0.9993, 1.0000, 0.9998, 1.0000, 0.9997],
#            device='cuda:0') TensorBase([12,  4, 15, 13,  9, 15,  9,  2, 15,  0, 15,  9,  0, 15, 15, 13, 15,
#             15, 15,  5,  1,  8, 15, 15, 10,  1,  0, 10, 15,  0, 15,  2, 11, 10,
#              2, 15,  3,  2,  3,  9, 15, 13, 15, 13,  5, 13,  6, 12,  2, 12,  9,
#             15,  3, 14, 15, 12, 15,  2, 15, 14,  7,  5,  2,  6],
#            device='cuda:0') tensor([12, 15, 15, 13,  9, 15,  9,  2, 15,  0, 15,  9,  0, 15, 15, 13, 15, 15,
#         15,  5,  1,  8, 15, 15, 10,  1,  0, 10, 15, 15, 15,  2, 11, 15,  2, 15,
#         15,  2,  3,  9, 15, 15, 15, 15,  5, 13,  6, 12,  2, 12,  9, 15,  3, 15,
#         15, 12, 15, 15, 15, 14,  7,  5,  2,  6], device='cuda:0')
# 872 / 1024 = Acc: 85.15625 %
# TensorBase([1.0000, 1.0000, 0.9996, 1.0000, 0.6977, 0.9999, 0.9996, 0.2235,
#             1.0000, 0.9963, 0.2708, 0.9967, 0.9380, 0.6372, 0.5293, 0.9938,
#             0.9990, 0.9999, 0.9999, 0.8316, 1.0000, 1.0000, 0.7895, 1.0000,
#             0.9994, 0.5886, 0.2505, 0.5035, 0.2944, 0.3130, 0.6101, 0.5399,
#             0.9996, 0.7387, 0.9998, 0.9956, 0.9999, 0.9997, 0.6029, 0.8336,
#             0.9998, 0.8803, 0.5015, 0.9999, 0.6971, 0.7656, 0.9999, 0.9999,
#             0.9587, 0.3436, 0.9995, 0.9999, 0.9999, 1.0000, 0.9996, 0.2310,
#             0.4836, 0.6930, 0.9995, 1.0000], device='cuda:0') TensorBase([ 0, 13,  7,  0, 13, 12, 10, 15,  3,  4, 15,  8, 14, 15, 15,  0,  7,
#             10,  8,  8,  3, 11, 14, 11,  7, 15, 15, 15, 15, 15, 15, 15, 10, 10,
#              6,  7, 11, 12, 15, 10,  7, 14, 15, 12,  1,  8, 12,  1,  1, 15,  8,
#              3,  6, 14,  9, 15, 15, 10,  0, 10], device='cuda:0') tensor([ 0, 13,  7,  0, 15, 12, 10, 15,  3,  4, 15,  8, 15, 15, 15,  0,  7, 10,
#          8, 15,  3, 11, 15, 11,  7, 15, 15, 15, 15, 15, 15, 15, 10, 15,  6,  7,
#         11, 12, 15, 15,  7, 15, 15, 12,  1, 15, 12,  1,  1, 15,  8,  3,  6, 14,
#          9, 15, 15, 15,  0, 10], device='cuda:0')
# 923 / 1084 = Acc: 85.14760147601476 %

# %%
predicted_cp, one_hot_labels_cp
# Out:
e1 = np.array([69.71375807940905, 72.29916897506925, 74.9769159741459, 77.93167128347184, 79.87072945521699, 81.4404432132964, 82.82548476454294, 84.57987072945522, 86.0572483841182, 87.44228993536473, 88.73499538319483])

ave19 = np.mean([a1, b1, c1, d1, e1], axis=0)

a2 = np.array([88.36565096952909, 91.87442289935365, 91.59741458910435, 93.62880886426593, 92.89012003693445, 93.90581717451524, 96.67590027700831, 95.10618651892891, 98.33795013850416, 95.38319482917821, 97.78393351800554])
b2 = np.array([87.90397045244691, 88.82733148661127, 91.59741458910435, 88.6426592797784, 91.2280701754386, 94.73684210526316, 94.73684210526316, 93.72114496768236, 95.93721144967682, 95.66020313942752, 97.04524469067405])
c2 = np.array([85.87257617728532, 87.53462603878117, 89.47368421052632, 91.59741458910435, 92.05909510618652, 93.25946445060019, 93.8134810710988, 95.01385041551247, 95.8448753462604, 96.67590027700831, 97.96860572483841])
d2 = np.array([86.88827331486611, 88.18097876269621, 89.38134810710989, 90.39704524469067, 91.5050784856879, 92.89012003693445, 94.45983379501385, 95.29085872576178, 96.02954755309327, 96.86057248384118, 97.4145891043398])
e2 = np.array([86.0572483841182, 87.16528162511543, 88.6426592797784, 91.13573407202216, 92.98245614035088, 94.73684210526316, 96.21421975992614, 97.4145891043398, 97.87626962142198, 98.15327793167128, 98.52262234533703])

ave24 = np.mean([a2, b2, c2, d2, e2], axis=0)

x = np.linspace(0.30, 0.80, 11)
y1 = ave14
y2 = ave19
y3 = ave24
y0 = [99.08, 99.08, 99.08, 99.08, 99.08, 99.08, 99.08, 99.08, 99.08, 99.08, 99.08]
plt.ylim(55, 100)
plt.xlabel("Threshold")
plt.ylabel("Accuracy [%]")
# plt.plot(x, y0, label="Openness=0, (threshold=0)")
plt.plot(x, y3, marker="o", label="Openness=0.087")
plt.plot(x, y2, marker="*", label="Openness=0.184")
plt.plot(x, y1, marker="x", label="Openness=0.293")
plt.legend()

# %%
x = np.linspace(0.30, 0.80, 11)
y1 = ave14

y_soft_center = [84.68, 89.66, 92.52, 95.57, 97.50, 98.24, 98.61,  98.98, 98.61, 98.43, 97.69]
y_triple = [80.81, 77.95,  74.72, 70.38, 67.43, 63.19, 59.68, 56.27, 54.33, 52.21, 50.92]
plt.ylim(55, 100)
plt.xlabel("Softmax threshold")
plt.ylabel("Accuracy [%]")
plt.plot(x, y_soft_center, marker="o", label="SoftMax + Center Loss")
plt.plot(x, y1, marker="x", label="Cross Entropy Loss")
plt.plot(x, y_triple, marker="*", label="Triple Joint Loss")

plt.legend()

# %% [markdown]
# model.two_vecsは 6817 * 64(batch_size) * 2になっちゃってる
#
# 正規化された値？訓練かテストのときの値なのか，softmaxを通っているのかはっきりさせる必要あり

# %%
two_vecs = model.two_vecs_train[-1].cpu().detach().numpy().copy()
x, y = zip(*two_vecs)
plt.scatter(x, y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 two_vecs = model.two_vecs_train[-1].cpu().detach().numpy().copy()
#       2 x, y = zip(*two_vecs)
#       3 plt.scatter(x, y)
#
# AttributeError: 'list' object has no attribute 'cpu'

# %%
two_vecs = model.two_vecs_test[2].cpu().detach().numpy().copy()
x, y = zip(*two_vecs)
plt.scatter(x, y)

# %%
len(model.two_vecs_test)
# Out:
# 51
