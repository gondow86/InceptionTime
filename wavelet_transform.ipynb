# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
wavelet
# Out:
# array([[-4.31902074e-08, -2.53624025e-05, -9.82044420e-06, ...,
#          1.75344782e-06,  1.76718159e-05,  4.56393652e-05],
#        [-1.51387982e-07, -2.47429175e-05, -3.36645685e-05, ...,
#          4.78020257e-05,  6.02480983e-05,  4.39716785e-05],
#        [-3.22722313e-07, -2.15279194e-05, -3.61519861e-05, ...,
#          7.27392319e-05,  6.39431648e-05,  3.73963171e-05],
#        ...,
#        [-2.72579770e-05, -3.48682056e-05, -4.24257556e-05, ...,
#          1.86739874e-05,  5.45325922e-06, -7.82901227e-06],
#        [-2.90378089e-05, -3.65240149e-05, -4.39593774e-05, ...,
#          1.72586841e-05,  4.23708036e-06, -8.83825440e-06],
#        [-3.08467475e-05, -3.82140650e-05, -4.55321198e-05, ...,
#          1.58967850e-05,  3.06402071e-06, -9.81560090e-06]])

# %%
for i in range(1, 30 + 1):
    file_name = "data/radar_%02d.csv" % i
    radar_frame = pd.read_csv(file_name)
    # print(file_name)
    heart_segment = radar_frame[:1250]
    heart_segment = np.array(heart_segment).flatten()
    # t = np.linspace(0, 5, 1250, endpoint=False)
    width = np.arange(1, 31)

    wavelet = signal.cwt(heart_segment, signal.ricker, width)
    plt.figure()
    if i == 1:
        # plt.imshow(wavelet, extent=[0, 5, 31, 1], cmap='PRGn', aspect='auto', vmax=abs(wavelet).max(), vmin=-abs(wavelet).max())
        plt.plot()
        plt.show()
    save_path = "data/wavelet_example_%02d.png" % i
    # plt.savefig(save_path)
# Out:
# /tmp/ipykernel_17021/2261657146.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %% [markdown]
# # sample code

# %%
from scipy import signal
import matplotlib.pyplot as plt
t = np.linspace(-1, 1, 200, endpoint=False)
sig  = np.cos(2 * np.pi * 7 * t) + signal.gausspulse(t - 0.4, fc=2)
widths = np.arange(1, 31)
cwtmatr = signal.cwt(sig, signal.ricker, widths)
plt.imshow(cwtmatr, extent=[-1, 1, 31, 1], cmap='PRGn', aspect='auto',
           vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max())
plt.show()
